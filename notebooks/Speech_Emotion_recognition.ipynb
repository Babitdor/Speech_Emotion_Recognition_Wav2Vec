# %% [markdown]
# import pandas as pd
# import librosa
# from sklearn.model_selection import train_test_split
# from IPython.display import Audio
# import random
# import json
# import os

# %%
emotion_data_path = "../data/Emotion_Speech_Data/"  # RASDEV
emotion_data_path_ESD = "../data/Emotion_Speech_Dataset/English"  # ESD Dataset

# %% [markdown]
# ### Preprocessing the RAVDESS Emotion Data Path

# %%
def emotion_label_tagger(emotion):
    #   Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised)
    labels = {
        "01": "neutral",
        "02": "calm",
        "03": "happy",
        "04": "sad",
        "05": "angry",
        "06": "fearful",
        "07": "disgust",
        "08": "surprise",
    }
    emotion_label = labels.get(emotion, "Unknown")
    return emotion_label

# %%
emotion_voice_data = []

for root, dirs, files in os.walk(emotion_data_path):
    for file in files:
        if file.endswith(".wav"):

            emotion = file.split("-")[2]
            emotion = emotion_label_tagger(emotion)
            audio_file = os.path.join(root, file)
            audio_name = audio_file.split("/")[3]
            audio_name_split = audio_name.split("\\")
            actor_name = audio_name_split[0]
            file_name = audio_name_split[1]

            entry = {
                # "Actor": actor_name,
                "Name": file,
                "path": audio_file,
                "emotion": emotion,
            }
            emotion_voice_data.append(entry)

    with open("../data/emotion_voice_data.json", "w") as f:
        json.dump(emotion_voice_data, f)

# %%
data = []
with open("../data/emotion_voice_data.json", "r") as f:
    data = pd.read_json(f)

df_1 = pd.DataFrame(data)
print(f"Shape of the Dataset : {df_1.shape}")
df_1.head(-1)
# Out:
# Shape of the Dataset : (1440, 3)
#                           Name  \
# 0     03-01-01-01-01-01-01.wav
# 1     03-01-01-01-01-02-01.wav
# 2     03-01-01-01-02-01-01.wav
# 3     03-01-01-01-02-02-01.wav
# 4     03-01-02-01-01-01-01.wav
# ...                        ...
# 1434  03-01-08-01-02-01-24.wav
# 1435  03-01-08-01-02-02-24.wav
# 1436  03-01-08-02-01-01-24.wav
# 1437  03-01-08-02-01-02-24.wav
# 1438  03-01-08-02-02-01-24.wav
#
#                                                    path   emotion
# 0     ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 1     ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 2     ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 3     ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 4     ../data/Emotion_Speech_Data/Actor_01\03-01-02-...      calm
# ...                                                 ...       ...
# 1434  ../data/Emotion_Speech_Data/Actor_24\03-01-08-...  surprise
# 1435  ../data/Emotion_Speech_Data/Actor_24\03-01-08-...  surprise
# 1436  ../data/Emotion_Speech_Data/Actor_24\03-01-08-...  surprise
# 1437  ../data/Emotion_Speech_Data/Actor_24\03-01-08-...  surprise
# 1438  ../data/Emotion_Speech_Data/Actor_24\03-01-08-...  surprise
#
# [1439 rows x 3 columns]

# %% [markdown]
# ### Filtering Three Emotions from RASDEV

# %%
df_1 = df_1[~df_1["emotion"].isin(["fearful", "disgust", "calm"])]

# %%
emotion_voice_data_ESD = []
# Path to the main directory
emotion_data_path = "../data/Emotion_Speech_Dataset/English"

# Dictionary to store the emotion labels and associated .wav files
emotion_files = {}

# Traverse the directory to capture emotion labels and .wav files
for session in os.listdir(emotion_data_path):
    session_path = os.path.join(emotion_data_path, session)

    # Skip non-directory entries like .DS_Store or text files
    if not os.path.isdir(session_path):
        continue

    for emotion in os.listdir(session_path):
        emotion_path = os.path.join(session_path, emotion)

        # Ensure the path is an emotion folder
        if os.path.isdir(emotion_path):
            wav_files = [f for f in os.listdir(emotion_path) if f.endswith(".wav")]

            # Add files to the dictionary under the current emotion
            if emotion not in emotion_files:
                emotion_files[emotion] = []

            # Add the full path to each wav file to the list
            for wav_file in wav_files:
                emotion_files[emotion].append(os.path.join(emotion_path, wav_file))

# Print the collected


for emotion, files in emotion_files.items():
    for file in files:
        name = file.split("\\")[3]
        entry = {
            # "Actor": actor_name,
            "Name": name,
            "path": file,
            "emotion": emotion.lower(),
        }
        emotion_voice_data_ESD.append(entry)


with open("../data/emotion_voice_data_ESD.json", "w") as f:
    json.dump(emotion_voice_data_ESD, f)

# %%
data = []
with open("../data/emotion_voice_data_ESD.json", "r") as f:
    data = pd.read_json(f)

df_2 = pd.DataFrame(data)
print(f"Shape of the Dataset : {df_2.shape}")
df_2.head(-1)
# Out:
# Shape of the Dataset : (17500, 3)
#                   Name                                               path  \
# 0      0011_000351.wav  ../data/Emotion_Speech_Dataset/English\0011\An...
# 1      0011_000352.wav  ../data/Emotion_Speech_Dataset/English\0011\An...
# 2      0011_000353.wav  ../data/Emotion_Speech_Dataset/English\0011\An...
# 3      0011_000354.wav  ../data/Emotion_Speech_Dataset/English\0011\An...
# 4      0011_000355.wav  ../data/Emotion_Speech_Dataset/English\0011\An...
# ...                ...                                                ...
# 17494  0020_001745.wav  ../data/Emotion_Speech_Dataset/English\0020\Su...
# 17495  0020_001746.wav  ../data/Emotion_Speech_Dataset/English\0020\Su...
# 17496  0020_001747.wav  ../data/Emotion_Speech_Dataset/English\0020\Su...
# 17497  0020_001748.wav  ../data/Emotion_Speech_Dataset/English\0020\Su...
# 17498  0020_001749.wav  ../data/Emotion_Speech_Dataset/English\0020\Su...
#
#         emotion
# 0         angry
# 1         angry
# 2         angry
# 3         angry
# 4         angry
# ...         ...
# 17494  surprise
# 17495  surprise
# 17496  surprise
# 17497  surprise
# 17498  surprise
#
# [17499 rows x 3 columns]

# %% [markdown]
# ### Combining the Datafram from two seperate Datasets

# %%
DF = pd.concat([df_1, df_2], ignore_index=True)
DF.head(-1)
# Out:
#                            Name  \
# 0      03-01-01-01-01-01-01.wav
# 1      03-01-01-01-01-02-01.wav
# 2      03-01-01-01-02-01-01.wav
# 3      03-01-01-01-02-02-01.wav
# 4      03-01-03-01-01-01-01.wav
# ...                         ...
# 18358           0020_001745.wav
# 18359           0020_001746.wav
# 18360           0020_001747.wav
# 18361           0020_001748.wav
# 18362           0020_001749.wav
#
#                                                     path   emotion
# 0      ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 1      ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 2      ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 3      ../data/Emotion_Speech_Data/Actor_01\03-01-01-...   neutral
# 4      ../data/Emotion_Speech_Data/Actor_01\03-01-03-...     happy
# ...                                                  ...       ...
# 18358  ../data/Emotion_Speech_Dataset/English\0020\Su...  surprise
# 18359  ../data/Emotion_Speech_Dataset/English\0020\Su...  surprise
# 18360  ../data/Emotion_Speech_Dataset/English\0020\Su...  surprise
# 18361  ../data/Emotion_Speech_Dataset/English\0020\Su...  surprise
# 18362  ../data/Emotion_Speech_Dataset/English\0020\Su...  surprise
#
# [18363 rows x 3 columns]

# %%
# Saving the csv for the combined Dataset
DF.to_csv("../data/complete_emotion_data.csv", sep="\t", encoding="utf-8", index=False)

# %% [markdown]
# #### Counting Individual Labels

# %%
print("Emotion Types: ", DF["emotion"].unique())
print()
DF.groupby("emotion").count()[["path"]]
# Out:
# Emotion Types:  ['neutral' 'happy' 'sad' 'angry' 'surprise']
#           path
# emotion
# angry     3692
# happy     3692
# neutral   3596
# sad       3692
# surprise  3692

# %% [markdown]
# ### Preview of Audios

# %%
id = random.randint(0, DF.shape[0])
print(f"ID Location: {id}\nAudio Name: {DF['Name'][id]}\nEmotion = {DF['emotion'][id]}")
Audio(DF["path"][id])
# Out:
# ID Location: 5413
# Audio Name: 0013_001050.wav
# Emotion = happy
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Sample only a certain amount from the complete Dataset

# %%
Audio_data = DF.sample(n=5000, random_state=101)
Audio_data = Audio_data.reset_index()

# %%
Data = Audio_data.drop(columns="index")

# %%
Data
# Out:
#                  Name                                               path  \
# 0     0012_001510.wav  ../data/Emotion_Speech_Dataset/English\0012\Su...
# 1     0016_000878.wav  ../data/Emotion_Speech_Dataset/English\0016\Ha...
# 2     0014_000425.wav  ../data/Emotion_Speech_Dataset/English\0014\An...
# 3     0014_001418.wav  ../data/Emotion_Speech_Dataset/English\0014\Su...
# 4     0013_000913.wav  ../data/Emotion_Speech_Dataset/English\0013\Ha...
# ...               ...                                                ...
# 4995  0013_000721.wav  ../data/Emotion_Speech_Dataset/English\0013\Ha...
# 4996  0015_000494.wav  ../data/Emotion_Speech_Dataset/English\0015\An...
# 4997  0016_001227.wav  ../data/Emotion_Speech_Dataset/English\0016\Sa...
# 4998  0013_000331.wav  ../data/Emotion_Speech_Dataset/English\0013\Ne...
# 4999  0018_000519.wav  ../data/Emotion_Speech_Dataset/English\0018\An...
#
#        emotion
# 0     surprise
# 1        happy
# 2        angry
# 3     surprise
# 4        happy
# ...        ...
# 4995     happy
# 4996     angry
# 4997       sad
# 4998   neutral
# 4999     angry
#
# [5000 rows x 3 columns]

# %%
data_save_path = "../data"

train_df, test_df = train_test_split(
    Data, test_size=0.2, random_state=100, stratify=Audio_data["emotion"]
)

train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

train_df.to_csv(
    f"{data_save_path}/emotion_train.csv", sep="\t", encoding="utf-8", index=False
)
test_df.to_csv(
    f"{data_save_path}/emotion_test.csv", sep="\t", encoding="utf-8", index=False
)

print(f"Train Data: {train_df.shape} | Test Data: {test_df.shape}")
# Out:
# Train Data: (4000, 3) | Test Data: (1000, 3)

# %%
from datasets import load_dataset

data_files_csv = {
    "train": "../data/emotion_train.csv",
    "validation": "../data/emotion_test.csv",
}

dataset = load_dataset("csv", data_files=data_files_csv, delimiter="\t")
train_dataset_csv = dataset["train"]
validation_dataset_csv = dataset["validation"]

print(train_dataset_csv)
print(validation_dataset_csv)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from datasets import load_dataset
#       3 data_files_csv = {
#       4     "train": "../data/emotion_train.csv",
#       5     "validation": "../data/emotion_test.csv",
#       6 }
#       8 dataset = load_dataset("csv", data_files=data_files_csv, delimiter="\t")
#
# ModuleNotFoundError: No module named 'datasets'

# %%
input_column = "path"
output_column = "emotion"

# %%
label_list = train_dataset_csv.unique(output_column)
label_list.sort()
num_labels = len(label_list)

print(f"{num_labels} Labels : {label_list}")
# Out:
# 5 Labels : ['angry', 'happy', 'neutral', 'sad', 'surprise']

# %% [markdown]
# ### Converting audio feators to vectors, typically through Short-Time Fourier Transform using Wav2Vec

# %%
from transformers import Wav2Vec2Processor, AutoConfig

# %%
MODEL_NAME = "facebook/wav2vec2-large-960h"
POOLING_MODE = "mean"

# %%
config = AutoConfig.from_pretrained(
    MODEL_NAME,
    num_labels=num_labels,
    label2id={label: i for i, label in enumerate(label_list)},
    id2label={i: label for i, label in enumerate(label_list)},
    finetuning_task="wav2vec2_clf",
)
setattr(config, "pooling_mode", POOLING_MODE)

# %%
processor = Wav2Vec2Processor.from_pretrained(MODEL_NAME)
target_sr = processor.feature_extractor.sampling_rate
print(f"The target sampling rate: {target_sr}")
# Out:
# The target sampling rate: 16000

# %%
print(f"train: {train_dataset_csv}")
print(f"validation: {validation_dataset_csv}")
# Out:
# train: Dataset({
#     features: ['Name', 'path', 'emotion'],
#     num_rows: 4000
# })
# validation: Dataset({
#     features: ['Name', 'path', 'emotion'],
#     num_rows: 1000
# })

# %%
import librosa


emotion_map = {
    "neutral": 0,
    "happy": 1,
    "sad": 2,
    "angry": 3,
    "surprise": 4,
}


def preprocess_audio(file_path, label):

    speech_array, sampling_rate = librosa.load(file_path, sr=16000)
    speech_array = speech_array.squeeze()

    inputs = processor(
        speech_array,
        sampling_rate=sampling_rate,
        padding=True,
        return_attention_mask=True,
    )

    label_id = emotion_map[label]

    return {
        "input_values": inputs["input_values"][0],
        "attention_mask": inputs["attention_mask"][0],
        "labels": label_id,
    }

# %%
def processing_data(_t_dataset_):
    dataset = []
    temp_df = pd.DataFrame(_t_dataset_)
    for _, row in temp_df.iterrows():
        processed_data = preprocess_audio(row["path"], row["emotion"])
        dataset.append(processed_data)

    return dataset

# %%
train_dataset = processing_data(train_dataset_csv)
validation_dataset = processing_data(validation_dataset_csv)
print(train_dataset)
print(validation_dataset)
# Out:
# [{'input_values': array([0.02848713, 0.02638132, 0.02638132, ..., 0.0232226 , 0.0221697 ,
#        0.02638132], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.06792314,  0.06439266,  0.05997958, ..., -0.02916474,
#        -0.03004735, -0.03004735], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00463632,  0.00463632,  0.00378897, ..., -0.07586167,
#        -0.07840371, -0.08264045], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.02681051, 0.02821871, 0.03103511, ..., 0.01061622, 0.01061622,
#        0.01061622], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.03729221,  0.03655714,  0.03802728, ..., -0.03400961,
#        -0.03621482, -0.0369499 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00283731,  0.00221435,  0.00221435, ..., -0.03454043,
#        -0.03454043, -0.03578635], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.0006774 ,  0.00023932,  0.00023932, ..., -0.0019511 ,
#        -0.00238918, -0.00326535], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.01466234,  0.01466234,  0.01466234, ..., -0.00801738,
#        -0.01068559, -0.01068559], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00117884, -0.00117884, -0.00058962, ...,  0.01885462,
#         0.01885462,  0.01767618], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.02025757, 0.0164016 , 0.01061765, ..., 0.04532136, 0.04821333,
#        0.04917732], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.03759912, -0.03759912, -0.03675513, ..., -0.03000319,
#        -0.02704922, -0.0287372 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.05853641, -0.05691236, -0.05528831, ...,  0.02753808,
#         0.02591403,  0.02591403], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.03860363, -0.03775974, -0.03691585, ...,  0.03059573,
#         0.02890794,  0.02553236], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.02652225,  0.02880104,  0.03411822, ..., -0.00386164,
#        -0.00158285,  0.00069594], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.02692512, -0.02513289, -0.02513289, ..., -0.01258721,
#        -0.01079497, -0.01079497], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.05503469, -0.05503469, -0.0543375 , ..., -0.00483708,
#        -0.00483708, -0.00623146], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.0316179 , -0.02894945, -0.026281  , ...,  0.23589414,
#         0.2338928 ,  0.23522703], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00817236,  0.02039367,  0.02989913, ..., -0.038676  ,
#        -0.04003392, -0.04274977], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.05547512,  0.05408546,  0.0526958 , ..., -0.01678724,
#        -0.01539758, -0.01956657], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00841983,  0.00841983,  0.00481134, ..., -0.012329  ,
#        -0.01413324, -0.012329  ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.04299356, -0.04030939, -0.04030939, ...,  0.03618956,
#         0.03753165,  0.03484748], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.16117711, 0.15411867, 0.14706025, ..., 0.00185829, 0.00034577,
#        0.00135412], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-9.7150998e-03, -1.8741840e-02, -2.0031374e-02, ...,
#         3.8250084e-03,  1.2459402e-03, -4.3593991e-05], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 3.7954729e-03,  9.0503570e-04, -5.8443380e-05, ...,
#        -1.9854016e-03, -1.5036620e-03, -1.5036620e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 1.0392362e-02,  1.0392362e-02,  1.0392362e-02, ...,
#         6.4374681e-04, -5.2582825e-05,  1.3400764e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.00546677, 0.00424486, 0.00302296, ..., 0.00057915, 0.0011901 ,
#        0.0011901 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.01593872,  0.01635922,  0.01635922, ..., -0.0126553 ,
#        -0.0126553 , -0.01223479], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.02422054, -0.02564161, -0.0213784 , ...,  0.00988512,
#         0.00704298,  0.00846405], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00660745, -0.01312341, -0.0075383 , ..., -0.02243191,
#        -0.02289733, -0.02336276], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.01095645, 0.01095645, 0.01095645, ..., 0.01570021, 0.01886271,
#        0.01728146], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.01998619,  0.01931871,  0.01798376, ..., -0.00738043,
#        -0.00738043, -0.00804791], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.01760833, 0.01760833, 0.01760833, ..., 0.0679337 , 0.06941386,
#        0.06941386], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.02896418, -0.02896418, -0.02896418, ...,  0.01663481,
#         0.01663481,  0.01593329], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-4.8095593e-05,  6.7404902e-04, -4.8095593e-05, ...,
#        -5.0598223e-02, -5.2764658e-02, -5.3486802e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.0224624, -0.0224624, -0.0235334, ...,  0.0032415,  0.0032415,
#         0.0032415], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 4.2246196e-05,  4.2246196e-05, -1.0973505e-03, ...,
#        -3.3765435e-03, -1.2493317e-02, -2.3889283e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.00119877, -0.00102483, -0.00120051, ..., -0.00174956,
#        -0.0032195 , -0.00192897], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.04904294,  0.04732245,  0.04388146, ..., -0.00343212,
#        -0.00343212, -0.00343212], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-4.3617259e-04, -4.3617259e-04, -7.3376464e-06, ...,
#        -9.0128714e-03, -9.0128714e-03, -9.4417064e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.01369798, 0.0156681 , 0.01665315, ..., 0.00286233, 0.00384738,
#        0.00384738], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.02064137, -0.01864658, -0.01864658, ...,  0.01260519,
#         0.01659478,  0.01393505], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.02934037, -0.02821329, -0.02821329, ...,  0.01236137,
#         0.01461552,  0.01574259], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.014483  , -0.01357775, -0.01312512, ..., -0.01221987,
#        -0.01040936, -0.01086199], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.00988654, -0.01031696, -0.00988654, ..., -0.02021679,
#        -0.02064721, -0.02107764], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.01599302, -0.02104192, -0.02524935, ...,  0.01514192,
#         0.0159834 ,  0.01682489], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.05197756, 0.05303761, 0.0551577 , ..., 0.00745557, 0.00745557,
#        0.00957567], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 5.8332761e-04,  5.5955785e-05,  5.5955785e-05, ...,
#         5.8332761e-04,  5.5955785e-05, -9.9878793e-04], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.00624962, 0.00739399, 0.00682181, ..., 0.00911053, 0.01025489,
#        0.00968271], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.03923841, -0.03662203, -0.03749416, ..., -0.0357499 ,
#        -0.03749416, -0.03836628], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 8.3437590e-06,  8.3437590e-06,  5.5391574e-04, ...,
#        -5.3722819e-04,  8.3437590e-06, -1.0828002e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.16129488, 0.15469569, 0.15057118, ..., 0.02271179, 0.02106199,
#        0.02353669], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.08285377, -0.08146229, -0.08076655, ...,  0.00202652,
#         0.00202652,  0.00480948], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.04493003, 0.04743653, 0.04242353, ..., 0.0173585 , 0.019865  ,
#        0.0223715 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.10915837, -0.11205992, -0.11109274, ..., -0.00953847,
#        -0.00857128, -0.01147284], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.00037895, -0.00015809,  0.00091598, ..., -0.0033803 ,
#        -0.0033803 , -0.00391734], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.01922294, -0.01880164, -0.01795903, ...,  0.02206476,
#         0.02164346,  0.02248606], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00487462,  0.00432523,  0.00377583, ..., -0.00336625,
#        -0.00391564, -0.00336625], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.03566204, 0.0343162 , 0.02624112, ..., 0.02422235, 0.02422235,
#        0.02556819], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00713992,  0.00611943,  0.0081604 , ..., -0.01173905,
#        -0.01173905, -0.01275953], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.10680944, -0.10329818, -0.09978692, ...,  0.08865076,
#         0.08982118,  0.09216203], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00112996, -0.00112996, -0.00267084, ..., -0.14597236,
#        -0.14751323, -0.15213586], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.02955695, 0.03303235, 0.03998313, ..., 0.0017538 , 0.0017538 ,
#        0.00262265], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01579072,  0.01742659,  0.01797189, ..., -0.00220393,
#        -0.00274922, -0.00165864], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00182304, 0.00182304, 0.00145175, ..., 0.09278946, 0.09390334,
#        0.09204689], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-4.9435650e-05, -1.1791905e-03, -4.9435650e-05, ...,
#        -2.6598671e-02, -3.0552814e-02, -3.1682570e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 1.6672842e-05, -7.4266351e-04, -7.4266351e-04, ...,
#         2.9630791e-02,  3.1149464e-02,  3.4186810e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.01261146, -0.01103171, -0.01103171, ..., -0.03077855,
#        -0.03077855, -0.02761905], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.03492171, -0.03083571, -0.03083571, ...,  0.00389529,
#         0.00798129,  0.00798129], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.04413185, 0.04333072, 0.04092736, ..., 0.00327469, 0.00567806,
#        0.00647918], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.0090724 , -0.02288575,  0.00474094, ..., -0.01786271,
#        -0.01911847, -0.02037423], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.02142083, -0.01754502, -0.01560712, ...,  0.00570983,
#         0.00667878,  0.00764773], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-1.2782933e-03, -3.5333054e-05,  2.4505875e-03, ...,
#         1.8291074e-03,  1.8291074e-03,  1.2076272e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.00716234,  0.00898068,  0.00898068, ..., -0.00011099,
#        -0.00192933, -0.00011099], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00010379, 0.00114315, 0.00010379, ..., 0.00945803, 0.00945803,
#        0.00945803], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.01147482, 0.01534715, 0.01147482, ..., 0.06568749, 0.06568749,
#        0.06955982], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-9.9018405e-05,  4.5529232e-04,  4.5529232e-04, ...,
#        -6.1073199e-02, -6.3290440e-02, -6.5507680e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00608871,  0.00782809,  0.00434933, ..., -0.05391985,
#        -0.0573986 , -0.05913798], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.01372916, 0.01497408, 0.01497408, ..., 0.00501476, 0.00501476,
#        0.00625968], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.0026442 ,  0.0026442 ,  0.0026442 , ..., -0.05440512,
#        -0.05192472, -0.05043647], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.2663651 ,  0.25986552,  0.25336596, ..., -0.03632921,
#        -0.03632921, -0.03725772], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([5.2955886e-04, 8.4862395e-06, 5.2955886e-04, ..., 5.2955886e-04,
#        5.2955886e-04, 8.4862395e-06], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.00307809, 0.00307809, 0.00638484, ..., 0.00803822, 0.00803822,
#        0.00473147], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-7.077160e-05, -7.077160e-05,  7.322182e-04, ...,  5.550157e-03,
#         5.550157e-03,  3.944177e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.03224777, -0.0303544 , -0.03224777, ..., -0.01142072,
#        -0.00763398, -0.01142072], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.00242005, 0.00122154, 0.00042253, ..., 0.04716447, 0.04636547,
#        0.04676497], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00547204,  0.00229786,  0.00229786, ..., -0.01568911,
#        -0.01674717, -0.01674717], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.07798774,  0.06930443,  0.0673748 , ..., -0.02428234,
#        -0.01849347, -0.19505407], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.004766  ,  0.00411337, -0.00044262, ..., -0.0002511 ,
#        -0.00012773, -0.0001882 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.00311107,  0.00090366, -0.00939757, ...,  0.08478511,
#         0.08552092,  0.08699252], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.00062366,  0.00062366,  0.00157338, ..., -0.15892935,
#        -0.16367795, -0.16842654], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.04255418, -0.02785042, -0.02948417, ..., -0.0352023 ,
#        -0.03601917, -0.03765292], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00420818, 0.00420818, 0.0034062 , ..., 0.20309938, 0.20470335,
#        0.20470335], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.00850762, 0.00850762, 0.00891201, ..., 0.00486815, 0.00527253,
#        0.00567692], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00022019,  0.00022019, -0.00046484, ..., -0.06006226,
#        -0.06074729, -0.06211735], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.1019592 , -0.09954151, -0.09631793, ..., -0.03829351,
#        -0.03587582, -0.03829351], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01894149,  0.02000913,  0.01965325, ...,  0.00043569,
#         0.00043569, -0.00027607], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.01180439, -0.01180439, -0.01135107, ...,  0.00904872,
#         0.00950205,  0.00950205], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.01361272, -0.01120151, -0.01023702, ...,  0.01917981,
#         0.01917981,  0.0201443 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.0167827 , 0.01571139, 0.0167827 , ..., 0.00821221, 0.00821221,
#        0.00821221], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00992522, -0.00992522, -0.00716424, ..., -0.02373013,
#        -0.02373013, -0.02373013], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.00953933, 0.00701476, 0.00196561, ..., 0.05939967, 0.04867023,
#        0.04362108], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00022995, -0.00022995, -0.00022995, ..., -0.00062278,
#        -0.00029496, -0.00022995], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00704853,  0.00704853,  0.00846205, ..., -0.00425962,
#        -0.00425962, -0.00331728], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.01706518, 0.0259672 , 0.01980426, ..., 0.00473931, 0.00473931,
#        0.00542408], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.00143594, -0.00062297, -0.00143594, ..., -0.01037862,
#        -0.00875268, -0.00712674], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 5.5031098e-05, -6.2889978e-04,  6.5210857e-04, ...,
#        -2.3467795e-04, -2.3356419e-04, -2.3430312e-04], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.06718184,  0.06409217,  0.06023007, ..., -0.02010154,
#        -0.02164637, -0.0224188 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.01731214, 0.0190645 , 0.02081686, ..., 0.02957866, 0.03308338,
#        0.03483574], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.0002488 , -0.00092664,  0.00042904, ...,  0.03228767,
#         0.03228767,  0.02822061], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.03398054,  0.03236042,  0.03236042, ..., -0.00976281,
#        -0.00976281, -0.00814268], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 1.1324062e-02,  7.5331796e-03,  3.2007417e-03, ...,
#         1.0345228e-03, -4.8586666e-05, -5.9014140e-04], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00507408, -0.00579543, -0.00507408, ...,  0.00358203,
#         0.00286068,  0.00286068], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00486836, -0.00010352, -0.00010352, ..., -0.00805852,
#        -0.00805852, -0.00606977], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.05570086, 0.03517634, 0.02118234, ..., 0.00625541, 0.00718835,
#        0.00625541], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.00753769,  0.00678971,  0.00379778, ..., -0.00443003,
#        -0.00293407, -0.005926  ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.00452056, -0.00901168, -0.01687114, ..., -0.01462558,
#        -0.01238002, -0.01238002], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01402408,  0.0132444 ,  0.01168505, ..., -0.01950194,
#        -0.02106129, -0.02262064], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.0497128 , -0.04350173, -0.04350173, ..., -0.02279818,
#        -0.02486854, -0.02486854], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 8.02761570e-05, -5.08106314e-04,  8.02761570e-05, ...,
#         1.21875450e-01,  1.24817364e-01,  1.28347650e-01], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 1.03875570e-01,  1.06978536e-01,  1.00772597e-01, ...,
#        -7.39692696e-05, -7.39692696e-05, -3.17694037e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.00309877, -0.00235462, -0.00161046, ...,  0.01104018,
#         0.01104018,  0.01178434], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00548542, 0.00548542, 0.00548542, ..., 0.00312235, 0.00863619,
#        0.00942388], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.0122238 ,  0.0122238 ,  0.01150395, ..., -0.00145334,
#        -0.00325296, -0.00109341], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.04472515, -0.04377317, -0.04091722, ..., -0.0247335 ,
#        -0.0247335 , -0.0247335 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01454605,  0.01454605,  0.0137357 , ..., -0.01705788,
#        -0.01705788, -0.0186786 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00021226,  0.00021226, -0.00015214, ..., -0.04898169,
#        -0.04788849, -0.04861728], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.02004587, -0.01807477, -0.01807477, ..., -0.02398805,
#        -0.02595915, -0.02595915], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.04381654, -0.04474974, -0.04288336, ...,  0.0103085 ,
#         0.01124169,  0.01124169], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01145049,  0.01030547,  0.0125955 , ..., -0.01030485,
#        -0.01144987, -0.01144987], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00687561, 0.00864677, 0.00510445, ..., 0.01041794, 0.00687561,
#        0.00864677], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.03857879, 0.03857879, 0.0369331 , ..., 0.0031965 , 0.00401934,
#        0.00566503], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 7.2410643e-05,  7.2410599e-05,  7.2410621e-05, ...,
#        -2.7562424e-03, -5.0226395e-04,  7.2410628e-05], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-1.2680909e-02, -1.4020853e-02, -1.4690825e-02, ...,
#         4.8556652e-05,  4.8556652e-05,  7.1852852e-04], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.01243683,  0.01295261,  0.01243683, ..., -0.05255123,
#        -0.05461434, -0.05719323], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.01003616,  0.01170728,  0.0092006 , ..., -0.00583945,
#        -0.00667501, -0.00583945], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.05813098, -0.05602369, -0.05180913, ...,  0.00192654,
#         0.0061411 ,  0.0008729 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.00933493,  0.00974237,  0.00933493, ..., -0.01022223,
#        -0.00981479, -0.00981479], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.00819242, 0.00901555, 0.00901555, ..., 0.00983869, 0.0123081 ,
#        0.01148497], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.00138279,  0.00138279,  0.00027286, ..., -0.12403958,
#        -0.12181971, -0.11959985], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01809973,  0.01809973,  0.01727243, ..., -0.03484754,
#        -0.03732944, -0.03815674], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.01596435, 0.01724543, 0.02044813, ..., 0.00443462, 0.00443462,
#        0.00443462], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.00547033, 0.01109619, 0.00968972, ..., 0.02234789, 0.02094142,
#        0.02094142], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.01993648, 0.01993648, 0.01993648, ..., 0.03230876, 0.03230876,
#        0.03540182], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.03768476,  0.03768476,  0.03569288, ..., -0.000161  ,
#         0.00183088,  0.00183088], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.01795696, 0.01393763, 0.00656886, ..., 0.00522908, 0.00723875,
#        0.00589897], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.01707296, 0.01862236, 0.01862236, ..., 0.00622715, 0.00467775,
#        0.00777655], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.05929782, 0.04691244, 0.02214169, ..., 0.02910847, 0.02910847,
#        0.03065664], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.05250388, -0.05250388, -0.0537486 , ...,  0.02093424,
#         0.01968953,  0.01968953], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.00062303, 0.00048007, 0.00065481, ..., 0.00026914, 0.00484304,
#        0.00332235], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.03144619, -0.0299889 , -0.02780298, ..., -0.03144619,
#        -0.03290347, -0.03363212], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.02351448, -0.02001599, -0.01914137, ...,  0.02284046,
#         0.0245897 ,  0.02546432], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.0545724 , -0.05666713, -0.05247768, ..., -0.05247768,
#        -0.05352504, -0.05247768], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.04591151, -0.04206848, -0.04591151, ..., -0.11892918,
#        -0.12661526, -0.12661526], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.05113817, -0.04700832, -0.0442551 , ..., -0.01947604,
#        -0.02085265, -0.01947604], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.08090026,  0.08090026,  0.07648042, ..., -0.02664922,
#        -0.02664922, -0.0281225 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-9.9932431e-06, -9.9932431e-06, -9.9932431e-06, ...,
#        -1.4174297e-05, -1.4535568e-05, -9.9932431e-06], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([3.1661903e-06, 9.1376941e-04, 1.8243728e-03, ..., 1.2751612e-02,
#        1.3662215e-02, 1.2751612e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.03646104,  0.03979   ,  0.03646104, ..., -0.04676311,
#        -0.04343414, -0.04343414], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.01260988, 0.01260988, 0.01260988, ..., 0.01009368, 0.00757748,
#        0.01009368], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.04302565, -0.04204773, -0.03324643, ...,  0.01956137,
#         0.01956137,  0.0205393 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.01714451,  0.01613546,  0.01613546, ..., -0.00656823,
#        -0.0060637 , -0.00656823], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00882205, -0.00924216, -0.00966227, ...,  0.00378121,
#         0.00420132,  0.00378121], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.0470083 , -0.04416148, -0.04131466, ...,  0.03270276,
#         0.03412617,  0.036973  ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.00676019, 0.00721961, 0.00676019, ..., 0.00032838, 0.00124721,
#        0.0007878 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.01977484,  0.01977484,  0.02039123, ..., -0.00796282,
#        -0.00796282, -0.00734643], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00788973, -0.01020433, -0.00974141, ...,  0.00784949,
#         0.00831241,  0.00784949], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.0259521 ,  0.02359733,  0.02418602, ..., -0.06117411,
#        -0.0623515 , -0.06529494], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.03068055, 0.03068055, 0.0251021 , ..., 0.00278826, 0.00278826,
#        0.00348557], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.07037824, -0.06599369, -0.06453217, ...,  0.02462059,
#         0.02608211,  0.02900515], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.02299218, 0.01833581, 0.01367945, ..., 0.09749405, 0.10215042,
#        0.11146315], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.02323149,  0.02323149,  0.0239819 , ..., -0.02029238,
#        -0.02554526, -0.03379979], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01127077, -0.01208169, -0.01127077, ..., -0.06398027,
#        -0.06316935, -0.06316935], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.01841254, 0.01635032, 0.01635032, ..., 0.01153846, 0.01153846,
#        0.01016365], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00639149,  0.00639149,  0.00544221, ..., -0.22048707,
#        -0.22143635, -0.2185885 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.00184136, 0.00184136, 0.00184136, ..., 0.00764058, 0.00570751,
#        0.00570751], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00082805, 0.00082805, 0.00082805, ..., 0.15799558, 0.15945761,
#        0.15945761], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.02145188, -0.02048345, -0.01854659, ...,  0.03568555,
#         0.03859084,  0.03859084], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-4.3246826e-05,  4.7721929e-04, -4.3246826e-05, ...,
#        -2.7107485e-02, -2.6587019e-02, -2.6587019e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 5.0316045e-05,  5.0322658e-05,  5.0312974e-05, ...,
#        -6.4572662e-02, -6.7708544e-02, -6.1503086e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.00686706, 0.00828812, 0.00828812, ..., 0.00047232, 0.00118284,
#        0.00047232], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.02800313, -0.02679422, -0.02800313, ...,  0.02156232,
#         0.0203534 ,  0.01914449], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.15734094, -0.15554135, -0.15554135, ...,  0.06940956,
#         0.07030937,  0.07300878], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.6552386 , 0.65629673, 0.65735483, ..., 0.14523196, 0.14734818,
#        0.14417386], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.00625419, -0.00625419, -0.00446765, ..., -0.02679939,
#        -0.02679939, -0.02769266], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.00131042, 0.00122215, 0.00119831, ..., 0.03094115, 0.03523263,
#        0.00120953], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00018972, -0.00277177, -0.00535382, ...,  0.05403337,
#         0.05919747,  0.06436158], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00165615, -0.00013395, -0.00013395, ..., -0.06254407,
#        -0.05949967, -0.05797747], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.05107392, -0.04971012, -0.04971012, ...,  0.0232533 ,
#         0.0246171 ,  0.0259809 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.07439144, -0.07564647, -0.0731364 , ...,  0.00718592,
#         0.01095103,  0.01597117], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.05887336, -0.05965637, -0.06122239, ...,  0.03195554,
#         0.03273855,  0.03195554], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01831043, -0.01734984, -0.01542867, ...,  0.02491597,
#         0.02491597,  0.02395538], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00836858, -0.00356982, -0.01465548, ..., -0.00186433,
#        -0.00271707, -0.00271707], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.06206376, 0.05984568, 0.06095472, ..., 0.00217564, 0.0010666 ,
#        0.0010666 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.06589577, -0.06385819, -0.06080183, ...,  0.00643814,
#         0.00745693,  0.00745693], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.03877673,  0.03524633,  0.03736456, ..., -0.01417924,
#        -0.01770964, -0.01700356], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 3.7709622e-05,  8.1867300e-04,  8.1867300e-04, ...,
#        -4.1353345e-02, -4.2134311e-02, -4.2915273e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.02003015,  0.01893134,  0.02003015, ..., -0.09204833,
#        -0.09314714, -0.09204833], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.0063733 , -0.0063733 , -0.0063733 , ..., -0.02946098,
#        -0.02946098, -0.03184936], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.00561466, -0.00561466, -0.00631339, ...,  0.02862285,
#         0.0300203 ,  0.03211648], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.09176818, -0.09025706, -0.09176818, ...,  0.11525483,
#         0.11525483,  0.11676595], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.00237227, -0.00312533, -0.00336406, ..., -0.002713  ,
#        -0.00436399, -0.00261747], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.00894024, 0.00666376, 0.01349322, ..., 0.05219351, 0.05219351,
#        0.05674649], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.07079501, -0.06677455, -0.06516636, ..., -0.03621906,
#        -0.03782724, -0.03943542], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.10795714, -0.10346582, -0.10346582, ..., -0.03909015,
#        -0.03909015, -0.03909015], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.02677019, -0.0308883 , -0.03397688, ...,  0.01338134,
#         0.01132229,  0.01132229], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00545717, -0.00545717, -0.0068322 , ..., -0.16496108,
#        -0.16633612, -0.16633612], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.08134045, -0.07990181, -0.07774386, ...,  0.04957581,
#         0.05029513,  0.05101445], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.04583069,  0.04416361,  0.04333007, ..., -0.01585129,
#        -0.01585129, -0.01585129], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.07233547, -0.07158182, -0.06856723, ...,  0.02940698,
#         0.02789968,  0.02940698], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.0001264 ,  0.00071259,  0.0001264 , ..., -0.02097613,
#        -0.02156231, -0.02273468], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.07520117, -0.07161638, -0.06982399, ..., -0.06982399,
#        -0.07430498, -0.07520117], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.00237647, -0.00237647, -0.00293381, ..., -0.17236629,
#        -0.17236629, -0.17348099], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.0006236 , -0.0006236 , -0.00117477, ...,  0.07654029,
#         0.08094966,  0.08866604], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00346383,  0.00216749, -0.00085729, ..., -0.00301786,
#        -0.00344997, -0.00344997], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-7.5929781e-04, -9.9788900e-05,  5.5972004e-04, ...,
#         3.1977557e-03,  1.8787379e-03,  1.8787379e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.0001857 ,  0.0001857 ,  0.0001857 , ..., -0.0017629 ,
#         0.00113634, -0.00048483], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.01050522, -0.00893009, -0.00814253, ..., -0.05382133,
#        -0.05382133, -0.0546089 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.03922746, -0.03835644, -0.0357434 , ..., -0.00264482,
#        -0.00351584, -0.00438685], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00053199, 0.0005282 , 0.00053306, ..., 0.00109967, 0.00099489,
#        0.00096354], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.06126888,  0.05928368,  0.05729849, ..., -0.01416856,
#        -0.01019816, -0.01565745], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.02989138,  0.028643  ,  0.02677044, ..., -0.01380188,
#        -0.01317769, -0.0125535 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00111281,  0.00111281,  0.00012125, ..., -0.04549059,
#        -0.04747372, -0.04747372], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.01172168, -0.00747812, -0.00694768, ...,  0.09489776,
#         0.09754998,  0.09914131], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.01475879, -0.01389114, -0.01389114, ...,  0.00085898,
#         0.00085898,  0.00085898], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00026246,  0.00093939, -0.00026246, ...,  0.00214124,
#         0.00334309,  0.00214124], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.09300696,  0.09571901,  0.1002391 , ..., -0.00914694,
#        -0.00733891, -0.00824293], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.00719941, 0.008232  , 0.008232  , ..., 0.01752529, 0.01804159,
#        0.01855788], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01625273, -0.01681995, -0.01625273, ..., -0.07127249,
#        -0.07297413, -0.07524299], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.02497475, 0.02181082, 0.02181082, ..., 0.00282727, 0.00599119,
#        0.00599119], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-7.7832614e-05, -7.7832614e-05, -7.7832614e-05, ...,
# ...
#        -0.3564412 , -0.36370128], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.01079543,  0.01043492,  0.01115593, ..., -0.00578763,
#        -0.00542713, -0.00578763], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 1.3416955e-02,  2.2970043e-02,  1.2580183e-02, ...,
#         2.8859274e-04, -7.4560172e-05,  1.3409466e-04], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.00333659, -0.00151758, -0.00109276, ...,  0.00041409,
#         0.00039615,  0.00041473], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.00168248, -0.00045797,  0.00239921, ..., -0.00576416,
#        -0.00535599, -0.00535599], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00512853, -0.00512853, -0.00617025, ..., -0.11034281,
#        -0.11034281, -0.11034281], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.01746829, 0.0162271 , 0.01746829, ..., 0.07456311, 0.0758043 ,
#        0.07828669], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.01395246, 0.02272048, 0.0200185 , ..., 0.00014968, 0.00024432,
#        0.00016264], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.0011613 , -0.00191421, -0.00040838, ..., -0.0659116 ,
#        -0.06817033, -0.07042906], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00466371, -0.00340424, -0.00466371, ..., -0.01348004,
#        -0.01348004, -0.01348004], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.00430433, -0.00838033, -0.00430433, ..., -0.02468434,
#        -0.02468434, -0.02876034], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.02918751, 0.02918751, 0.02918751, ..., 0.07636332, 0.0793118 ,
#        0.08520878], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00758094,  0.00672383,  0.00672383, ..., -0.01641816,
#        -0.01556105, -0.01556105], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00447421, -0.0075705 , -0.00768781, ...,  0.00365582,
#         0.00334723,  0.00509146], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.0004646 ,  0.0004646 ,  0.0004646 , ..., -0.06292991,
#        -0.06181773, -0.06515428], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.01884908, -0.01762317, -0.01884908, ..., -0.00536398,
#        -0.00536398, -0.00413806], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01353826, -0.01425126, -0.01425126, ...,  0.00143485,
#         0.00214786,  0.00571288], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00499485,  0.00549689,  0.00298668, ..., -0.00554803,
#        -0.00454394, -0.00504598], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.03502622, 0.04565375, 0.0584068 , ..., 0.02227317, 0.02014767,
#        0.0169594 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.12947614, -0.12716806, -0.12255188, ...,  0.00670113,
#         0.00670113,  0.00785518], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.02288511, -0.0211769 , -0.01989575, ..., -0.0194687 ,
#        -0.01989575, -0.0203228 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([0.00207292, 0.00207292, 0.00207292, ..., 0.01778588, 0.01617429,
#        0.0153685 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.04358786, 0.04205292, 0.04205292, ..., 0.00444702, 0.00444702,
#        0.00291208], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-1.6458438e-05, -1.6458438e-05, -1.6458438e-05, ...,
#         6.0721997e-02,  6.3325070e-02,  6.6795841e-02], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.16873811, -0.16436388, -0.1570735 , ...,  0.00914721,
#         0.00914721,  0.00914721], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.0212865 , -0.02016843, -0.02016843, ...,  0.05362416,
#         0.05697837,  0.0558603 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.06559794, 0.06724013, 0.06724013, ..., 0.02618526, 0.02618526,
#        0.02782745], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.02960352,  0.02604258,  0.02366861, ..., -0.04992428,
#        -0.04992428, -0.04992428], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.00308549, -0.00616246, -0.00462398, ..., -0.01539336,
#        -0.01539336, -0.01693184], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.06801952,  0.07145298,  0.07831992, ..., -0.1912073 ,
#        -0.19034894, -0.19206567], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01395102, -0.01139908, -0.01139908, ...,  0.02687996,
#         0.0294319 ,  0.0294319 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.00458402, 0.00392243, 0.00259924, ..., 0.02310868, 0.02310868,
#        0.02575506], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.00786321, 0.01161848, 0.01161848, ..., 0.00504676, 0.00504676,
#        0.00410794], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.01096688, -0.00786285, -0.01096688, ...,  0.04490576,
#         0.04335374,  0.04490576], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.03700763, 0.03610398, 0.03429668, ..., 0.01893468, 0.01893468,
#        0.02074197], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 0.05956002,  0.0583419 ,  0.05712378, ..., -0.02205423,
#        -0.02083611, -0.02205423], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.06425094,  0.06425094,  0.06315307, ..., -0.02138294,
#        -0.02357868, -0.02357868], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-8.6834939e-04, -5.9133592e-05, -8.6834939e-04, ...,
#        -8.6834939e-04, -2.4867812e-03, -1.6775653e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.04617476,  0.04269779,  0.04356704, ..., -0.00250274,
#        -0.00337199, -0.00424123], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.01047374,  0.01102643,  0.01047374, ..., -0.0177133 ,
#        -0.01716062, -0.01881868], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.00489852, 0.00552505, 0.0080312 , ..., 0.01805581, 0.02056196,
#        0.02432118], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.03867384, -0.03867384, -0.03781584, ...,  0.0531319 ,
#         0.05570589,  0.05742189], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.06117192, 0.06024617, 0.05839467, ..., 0.1741136 , 0.17689085,
#        0.18244536], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([-0.00531691, -0.00237721, -0.00237721, ...,  0.01702479,
#         0.01761273,  0.01702479], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.05690815, -0.05330376, -0.051862  , ...,  0.00508744,
#         0.00508744,  0.00508744], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00890066,  0.00741001,  0.00666469, ..., -0.01271371,
#        -0.01420435, -0.01345903], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.00015997,  0.00015997,  0.00015997, ..., -0.00205154,
#        -0.00131437, -0.00278871], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.0001256 , -0.00012362, -0.00012499, ..., -0.00012448,
#        -0.00012448, -0.00012448], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.10959882, -0.10558268, -0.10076331, ...,  0.00686935,
#         0.00767258,  0.00767258], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.02463844,  0.02463844,  0.02463844, ..., -0.01234232,
#        -0.01416104, -0.01476728], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.01147303,  0.00832937,  0.0146167 , ..., -0.02310727,
#        -0.02415516, -0.02415516], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00841472, -0.00841472, -0.00841472, ..., -0.00175111,
#        -0.00175111, -0.00230641], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.01467403, -0.0161497 , -0.01319837, ...,  0.04877944,
#         0.0502551 ,  0.05468209], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([ 0.00181521,  0.00569783,  0.00472717, ...,  0.00084455,
#        -0.00109676, -0.00206741], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.00071112, -0.00071112,  0.00476246, ...,  0.00085276,
#         0.00476246,  0.0055444 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 7.0574722e-04, -2.9686382e-05, -2.9686382e-05, ...,
#        -7.3840227e-03, -5.9131556e-03, -8.1194565e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.01125246,  0.02507325,  0.01211626, ..., -0.01034252,
#        -0.01034252, -0.01034252], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([ 0.00756961,  0.00640916,  0.00640916, ..., -0.04987263,
#        -0.05045285, -0.05277375], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.01817101, -0.02006823, -0.02006823, ...,  0.00839012,
#         0.01028735,  0.01218457], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01694111, -0.01694111, -0.01771115, ..., -0.01617106,
#        -0.01771115, -0.0184812 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.122643  , -0.11977026, -0.11881268, ..., -0.14754012,
#        -0.1494553 , -0.15232803], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([ 5.1846062e-05,  5.1846062e-05,  5.1846062e-05, ...,
#        -7.1830675e-03, -5.0125932e-03, -5.7360847e-03], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.00131225,  0.0030692 ,  0.0030692 , ..., -0.0540317 ,
#        -0.05491017, -0.05842407], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([ 0.00439199,  0.00365259,  0.00661019, ..., -0.02222644,
#        -0.02370524, -0.02444464], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-7.7936350e-04,  1.3394384e-05,  1.3394384e-05, ...,
#         2.3916680e-03,  8.0615224e-04,  1.3394384e-05], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.00426806, 0.01438121, 0.02016016, ..., 0.02449437, 0.02304963,
#        0.0216049 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.01222258, 0.01375392, 0.01375392, ..., 0.0221763 , 0.02294197,
#        0.02294197], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([-0.04345874, -0.0458315 , -0.05057701, ..., -0.00312191,
#        -0.00193553, -0.00193553], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.01907943, -0.01831601, -0.0175526 , ..., -0.02595017,
#        -0.027477  , -0.02900383], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([0.01124986, 0.00928612, 0.01272267, ..., 0.01124986, 0.0117408 ,
#        0.01026799], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}, {'input_values': array([0.0085473 , 0.00925789, 0.00925789, ..., 0.00783672, 0.0085473 ,
#        0.0085473 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([-0.00680576, -0.0090628 , -0.0090628 , ..., -0.01696245,
#        -0.01696245, -0.01809097], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([-0.05389206, -0.05280154, -0.05116575, ...,  0.01208472,
#         0.01262998,  0.01372051], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 3}, {'input_values': array([ 0.01137556,  0.01137556,  0.01379874, ..., -0.02174118,
#        -0.019318  , -0.0160871 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 2}, {'input_values': array([0.00051816, 0.00812867, 0.01517543, ..., 0.01292046, 0.01292046,
#        0.0134842 ], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 4}, {'input_values': array([-0.02209874, -0.02209874, -0.02032684, ...,  0.00890962,
#         0.00713771,  0.00447985], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 0}, {'input_values': array([0.00066495, 0.00151986, 0.00151986, ..., 0.01434361, 0.01434361,
#        0.01519853], dtype=float32), 'attention_mask': array([1, 1, 1, ..., 1, 1, 1], dtype=int32), 'labels': 1}]

# %%
idx = 0
print(f"Training input_values: {train_dataset[idx]['input_values']}")
print(f"Training Attention masks: {train_dataset[idx]['attention_mask']}")
print(f"Training label: {train_dataset[idx]['labels']}")
# Out:
# Training input_values: [0.02848713 0.02638132 0.02638132 ... 0.0232226  0.0221697  0.02638132]
# Training Attention masks: [1 1 1 ... 1 1 1]
# Training label: 1

# %% [markdown]
# ### MODEL

# %%
from dataclasses import dataclass
from typing import Optional, Tuple
import torch
from transformers.file_utils import ModelOutput


@dataclass
class SpeechClassificationOutput(ModelOutput):
    loss: Optional[torch.FloatTensor] = None
    logits: torch.FloatTensor = None
    hidden_states: Optional[Tuple[torch.FloatTensor]] = None
    attentions: Optional[Tuple[torch.FloatTensor]] = None

# %%
import torch
import torch.nn as nn
from torch.nn import BCEWithLogitsLoss, CrossEntropyLoss, MSELoss

from transformers.models.wav2vec2.modeling_wav2vec2 import (
    Wav2Vec2PreTrainedModel,
    Wav2Vec2Model,
)


class Wav2Vec2ClassificationHead(nn.Module):
    """Head for wav2vec classification task."""

    def __init__(self, config):
        super().__init__()
        self.dense = nn.Linear(config.hidden_size, config.hidden_size)
        self.dropout = nn.Dropout(config.final_dropout)
        self.out_proj = nn.Linear(config.hidden_size, config.num_labels)

    def forward(self, features, **kwargs):
        x = features
        x = self.dropout(x)
        x = self.dense(x)
        x = torch.tanh(x)
        x = self.dropout(x)
        x = self.out_proj(x)
        return x


class Wav2Vec2ForSpeechClassification(Wav2Vec2PreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.pooling_mode = config.pooling_mode
        self.config = config

        self.wav2vec2 = Wav2Vec2Model(config)
        self.classifier = Wav2Vec2ClassificationHead(config)

        self.init_weights()

    def freeze_feature_extractor(self):
        self.wav2vec2.feature_extractor._freeze_parameters()

    def merged_strategy(self, hidden_states, mode="mean"):
        if mode == "mean":
            outputs = torch.mean(hidden_states, dim=1)
        elif mode == "sum":
            outputs = torch.sum(hidden_states, dim=1)
        elif mode == "max":
            outputs = torch.max(hidden_states, dim=1)[0]
        else:
            raise Exception(
                "The pooling method hasn't been defined! Your pooling mode must be one of these ['mean', 'sum', 'max']"
            )

        return outputs

    def forward(
        self,
        input_values,
        attention_mask=None,
        output_attentions=None,
        output_hidden_states=None,
        return_dict=None,
        labels=None,
    ):
        return_dict = (
            return_dict if return_dict is not None else self.config.use_return_dict
        )
        outputs = self.wav2vec2(
            input_values,
            attention_mask=attention_mask,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )
        hidden_states = outputs[0]
        hidden_states = self.merged_strategy(hidden_states, mode=self.pooling_mode)
        logits = self.classifier(hidden_states)

        loss = None

        if labels is not None:
            if self.config.problem_type is None:
                if self.num_labels == 1:
                    self.config.problem_type = "regression"
                elif self.num_labels > 1 and labels.dtype in (torch.long, torch.int):
                    self.config.problem_type = "single_label_classification"
                else:
                    self.config.problem_type = "multi_label_classification"

            if self.config.problem_type == "regression":
                loss_fct = MSELoss()
                loss = loss_fct(logits.view(-1, self.num_labels), labels.float())
            elif self.config.problem_type == "single_label_classification":
                loss_fct = CrossEntropyLoss()
                loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
            elif self.config.problem_type == "multi_label_classification":
                loss_fct = BCEWithLogitsLoss()
                loss = loss_fct(logits, labels.float())
        else:
            loss = None

        if not return_dict:
            output = (logits,) + outputs[2:]
            return ((loss,) + output) if loss is not None else output

        return SpeechClassificationOutput(
            loss=loss,
            logits=logits,
            hidden_states=outputs.hidden_states,
            attentions=outputs.attentions,
        )

# %% [markdown]
# ### Data Augmentation

# %%
import random
import torchaudio
import torch
import librosa


def apply_spec_augment(waveform, sample_rate):
    spectrogram = torchaudio.transforms.MelSpectrogram(sample_rate)(waveform)
    spectrogram = torchaudio.transforms.TimeMasking(time_mask_param=20)(spectrogram)
    spectrogram = torchaudio.transforms.FrequencyMasking(freq_mask_param=20)(
        spectrogram
    )
    return spectrogram


def add_noise(waveform, noise_factor=0.005):
    noise = torch.randn(waveform.size()) * noise_factor
    return waveform + noise


def pitch_shift(waveform, sample_rate, n_steps=2):
    waveform_np = waveform.numpy().squeeze()
    shifted = librosa.effects.pitch_shift(
        y=waveform_np, sr=sample_rate, n_steps=n_steps
    )
    return torch.from_numpy(shifted).unsqueeze(0)


def volume_perturb(waveform, gain_db=5):
    gain_factor = 10 ** (gain_db / 20)
    return waveform * gain_factor

# %%
from dataclasses import dataclass
from typing import Dict, List, Optional, Union
import torch
from transformers import Wav2Vec2Processor


@dataclass
class DataCollatorCTCWithPadding:

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(
        self, features: List[Dict[str, Union[List[int], torch.Tensor]]]
    ) -> Dict[str, torch.Tensor]:

        # Augmentation of Data

        # for feature in features:
        #     waveform = torch.tensor(feature["input_values"])

        #     augmentation = random.choice(["S", "N", "P", "V"])
        #     if augmentation == "S":
        #         waveform = apply_spec_augment(
        #             waveform, self.processor.feature_extractor.sampling_rate
        #         )
        #     elif augmentation == "N":
        #         waveform = add_noise(waveform)
        #     elif augmentation == "P":
        #         waveform = pitch_shift(
        #             waveform, self.processor.feature_extractor.sampling_rate
        #         )
        #     else:
        #         waveform = volume_perturb(waveform)

        #     feature["input_values"] = waveform.squeeze().tolist()

        input_features = [
            {"input_values": feature["input_values"]} for feature in features
        ]
        label_features = [feature["labels"] for feature in features]

        d_type = torch.long if isinstance(label_features[0], int) else torch.float

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )

        batch["labels"] = torch.tensor(label_features, dtype=d_type)

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
is_regression = False

# %%
import numpy as np
from transformers import EvalPrediction


def compute_metrics(p: EvalPrediction):
    preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    preds = np.squeeze(preds) if is_regression else np.argmax(preds, axis=1)

    if is_regression:
        return {"mse": ((preds - p.label_ids) ** 2).mean().item()}
    else:
        return {"accuracy": (preds == p.label_ids).astype(np.float32).mean().item()}

# %%
model = Wav2Vec2ForSpeechClassification.from_pretrained(
    MODEL_NAME,
    config=config,
)
# Out:
# Some weights of Wav2Vec2ForSpeechClassification were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="../models",
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=1,
    eval_strategy="epoch",
    num_train_epochs=1,
    fp16=True,
    save_steps=100,
    eval_steps=100,
    logging_steps=100,
    learning_rate=1e-4,
    save_total_limit=2,
)

# %%
from typing import Any, Dict, Union

import torch

# from packaging import version
from torch import nn

from transformers import Trainer


class CTCTrainer(Trainer):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        if self.args.fp16:
            self.scaler = torch.amp.GradScaler("cuda")

    def training_step(
        self, model: nn.Module, inputs: Dict[str, Union[torch.Tensor, Any]], hiddens
    ) -> torch.Tensor:

        model.train()
        inputs = self._prepare_inputs(inputs)

        # Compute loss with mixed-precision (AMP) if enabled
        if self.args.fp16:
            with torch.amp.autocast("cuda"):
                loss = self.compute_loss(model, inputs)
        else:
            loss = self.compute_loss(model, inputs)

        # Scale loss for gradient accumulation
        if self.args.gradient_accumulation_steps > 1:
            loss = loss / self.args.gradient_accumulation_steps

        # Backpropagation with AMP if enabled
        if self.args.fp16:
            self.scaler.scale(loss).backward()
        else:
            loss.backward()

        return loss.detach()

# %%
trainer = CTCTrainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    processing_class=processor.feature_extractor,
)

# %%
trainer.train()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# {'loss': 1.593, 'grad_norm': 8.38288688659668, 'learning_rate': 9.5e-05, 'epoch': 0.05}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6608, 'grad_norm': 4.133175849914551, 'learning_rate': 9e-05, 'epoch': 0.1}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6588, 'grad_norm': 7.959367275238037, 'learning_rate': 8.5e-05, 'epoch': 0.15}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6274, 'grad_norm': 5.258180618286133, 'learning_rate': 8e-05, 'epoch': 0.2}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6909, 'grad_norm': 4.131208896636963, 'learning_rate': 7.500000000000001e-05, 'epoch': 0.25}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6624, 'grad_norm': 4.767113208770752, 'learning_rate': 7e-05, 'epoch': 0.3}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6745, 'grad_norm': 4.166616439819336, 'learning_rate': 6.500000000000001e-05, 'epoch': 0.35}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6493, 'grad_norm': 4.271084785461426, 'learning_rate': 6e-05, 'epoch': 0.4}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6457, 'grad_norm': 3.775951385498047, 'learning_rate': 5.500000000000001e-05, 'epoch': 0.45}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6243, 'grad_norm': 4.286005973815918, 'learning_rate': 5e-05, 'epoch': 0.5}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6343, 'grad_norm': 3.3446810245513916, 'learning_rate': 4.5e-05, 'epoch': 0.55}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6323, 'grad_norm': 7.0823163986206055, 'learning_rate': 4e-05, 'epoch': 0.6}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6541, 'grad_norm': 3.5845134258270264, 'learning_rate': 3.5e-05, 'epoch': 0.65}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6211, 'grad_norm': 3.2604148387908936, 'learning_rate': 3e-05, 'epoch': 0.7}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6386, 'grad_norm': 3.27030086517334, 'learning_rate': 2.5e-05, 'epoch': 0.75}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6404, 'grad_norm': 3.524282932281494, 'learning_rate': 2e-05, 'epoch': 0.8}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6263, 'grad_norm': 3.7606749534606934, 'learning_rate': 1.5e-05, 'epoch': 0.85}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6099, 'grad_norm': 3.3493874073028564, 'learning_rate': 1e-05, 'epoch': 0.9}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6038, 'grad_norm': 3.6557860374450684, 'learning_rate': 5e-06, 'epoch': 0.95}
# d:\Personal Projects\Speech\SpeechEmotionRecognition\.venv\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# {'loss': 1.6018, 'grad_norm': 5.040419101715088, 'learning_rate': 0.0, 'epoch': 1.0}
#   0%|          | 0/500 [00:00<?, ?it/s]
# {'eval_loss': 1.6124515533447266, 'eval_accuracy': 0.2029999941587448, 'eval_runtime': 588.1733, 'eval_samples_per_second': 1.7, 'eval_steps_per_second': 0.85, 'epoch': 1.0}
# {'train_runtime': 9296.8643, 'train_samples_per_second': 0.43, 'train_steps_per_second': 0.215, 'train_loss': 1.6374838943481445, 'epoch': 1.0}
# TrainOutput(global_step=2000, training_loss=1.6374838943481445, metrics={'train_runtime': 9296.8643, 'train_samples_per_second': 0.43, 'train_steps_per_second': 0.215, 'total_flos': 3.846948651312312e+17, 'train_loss': 1.6374838943481445, 'epoch': 1.0})

# %%
import librosa
from sklearn.metrics import classification_report

# %%
test_dataset = load_dataset(
    "csv", data_files={"test": "../data/emotion_test.csv"}, delimiter="\t"
)["test"]
test_dataset
# Out:
# Dataset({
#     features: ['Name', 'path', 'emotion'],
#     num_rows: 1000
# })

# %%
test_dataset = test_dataset.select(range(500))

# Display the subset
print(test_dataset)
# Out:
# Dataset({
#     features: ['Name', 'path', 'emotion'],
#     num_rows: 500
# })

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cpu

# %%
def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    speech_array = speech_array.squeeze().numpy()
    speech_array = librosa.resample(
        y=np.asarray(speech_array),
        orig_sr=sampling_rate,
        target_sr=processor.feature_extractor.sampling_rate,
    )
    print(speech_array)

    batch["speech"] = speech_array
    return batch


def predict(batch):
    features = processor(
        batch["speech"],
        sampling_rate=processor.feature_extractor.sampling_rate,
        return_tensors="pt",
        padding=True,
        return_attention_mask=True,
    )

    input_values = features.input_values.to(device)
    attention_mask = features.attention_mask.to(device)

    with torch.no_grad():
        logits = model(input_values, attention_mask=attention_mask).logits

    pred_ids = torch.argmax(logits, dim=-1).detach().cpu().numpy()
    batch["predicted"] = pred_ids
    return batch

# %%
test_dataset = test_dataset.map(speech_file_to_array_fn)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# [-0.00036621 -0.00042725 -0.00036621 ... -0.00021362 -0.00018311
#  -0.00018311]
# [1.0375977e-03 9.7656250e-04 9.4604492e-04 ... 1.5258789e-04 9.1552734e-05
#  9.1552734e-05]
# [ 0.00082397  0.00115967  0.00128174 ... -0.00054932 -0.0005188
#  -0.00036621]
# [-3.3569336e-04 -3.6621094e-04 -3.0517578e-04 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05]
# [ 0.0027771   0.00283813  0.0027771  ... -0.00018311 -0.00021362
#  -0.00021362]
# [ 0.0000000e+00  6.1035156e-05 -3.0517578e-05 ...  1.0375977e-03
#   1.0375977e-03  1.0070801e-03]
# [9.1552734e-05 6.1035156e-05 3.0517578e-05 ... 8.8500977e-04 9.1552734e-04
#  8.8500977e-04]
# [ 0.00024414  0.00027466  0.00024414 ... -0.00018311 -0.00024414
#  -0.00024414]
# [-1.8310547e-04 -1.8310547e-04 -1.5258789e-04 ...  1.5258789e-04
#   1.5258789e-04  9.1552734e-05]
# [2.1362305e-04 1.8310547e-04 2.1362305e-04 ... 6.1035156e-05 9.1552734e-05
#  6.1035156e-05]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  5.6152344e-03
#   5.5236816e-03  5.4626465e-03]
# [-3.6379788e-12 -5.4569682e-12 -3.6379788e-12 ...  1.6551108e-05
#   6.5184677e-06  7.8265184e-06]
# [0.00027466 0.00024414 0.00021362 ... 0.00015259 0.00015259 0.00018311]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  5.5139924e-07
#  -5.1605616e-07  0.0000000e+00]
# [-0.00152588 -0.0015564  -0.00152588 ...  0.00045776  0.00042725
#   0.00039673]
# [ 1.2207031e-04  9.1552734e-05  9.1552734e-05 ... -1.8310547e-04
#  -1.8310547e-04 -2.1362305e-04]
# [ 0.00036621  0.00036621  0.00039673 ... -0.00039673 -0.00042725
#  -0.00039673]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  7.8735352e-03
#   7.9040527e-03  7.8430176e-03]
# [ 0.00283813  0.00289917  0.00299072 ... -0.00357056 -0.00372314
#  -0.0038147 ]
# [-0.00073242 -0.0007019  -0.00067139 ...  0.00061035  0.00064087
#   0.00064087]
# [-0.00036621 -0.00033569 -0.00027466 ... -0.00253296 -0.00253296
#  -0.00262451]
# [-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ... -8.5449219e-04
#  -8.5449219e-04 -8.2397461e-04]
# [-0.00061035 -0.00057983 -0.00061035 ...  0.0015564   0.00158691
#   0.00167847]
# [-0.00036621 -0.00033569 -0.00030518 ...  0.00064087  0.00067139
#   0.00067139]
# [-0.00109863 -0.00149536 -0.00158691 ...  0.0005188   0.00048828
#   0.00048828]
# [4.0496430e-05 5.9798440e-05 5.2024800e-05 ... 7.8340017e-05 5.8280155e-05
#  5.5459339e-05]
# [-0.00012207 -0.00015259 -0.00018311 ...  0.00021362  0.00018311
#   0.00018311]
# [ 0.0000000e+00 -1.5258789e-04 -2.1362305e-04 ... -1.2207031e-04
#  -9.1552734e-05 -1.2207031e-04]
# [-0.00115967  0.00112915 -0.00033569 ... -0.00057983 -0.0005188
#  -0.0005188 ]
# [ 0.00057983  0.00061035  0.00015259 ... -0.00021362 -0.00024414
#  -0.00021362]
# [0.00436401 0.00427246 0.00411987 ... 0.00039673 0.00036621 0.00045776]
# [-3.0517578e-04 -3.0517578e-04 -3.0517578e-04 ... -1.5258789e-04
#  -1.2207031e-04 -9.1552734e-05]
# [0.00015259 0.00018311 0.00012207 ... 0.00036621 0.00033569 0.00033569]
# [-0.00036621 -0.00039673 -0.00039673 ... -0.00109863 -0.00112915
#  -0.00109863]
# [-2.4414062e-04 -1.5258789e-04  3.0517578e-05 ...  8.8500977e-04
#   9.7656250e-04  1.0986328e-03]
# [-0.00054932 -0.00061035 -0.00064087 ...  0.00054932  0.00054932
#   0.00054932]
# [0.00027466 0.00036621 0.00036621 ... 0.00039673 0.00033569 0.00036621]
# [0.00030518 0.00039673 0.00045776 ... 0.00305176 0.00317383 0.00320435]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -4.9743652e-03
#  -5.0048828e-03 -5.0048828e-03]
# [ 2.4414062e-04  1.8310547e-04  1.5258789e-04 ... -3.0517578e-04
#  -3.0517578e-05  9.1552734e-05]
# [-0.00061035 -0.00061035 -0.00057983 ...  0.00012207  0.00018311
#   0.00030518]
# [ 0.00057983  0.00054932  0.0005188  ...  0.         -0.00012207
#  -0.00012207]
# [0.00164795 0.00161743 0.00137329 ... 0.00210571 0.00213623 0.00216675]
# [-3.0517578e-05 -6.1035156e-05 -6.1035156e-05 ... -1.5258789e-04
#  -1.8310547e-04 -2.4414062e-04]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  4.5484967e-06
#  -3.1131071e-06  2.3783191e-06]
# [-0.00222778 -0.00216675 -0.00213623 ...  0.00213623  0.00222778
#   0.0022583 ]
# [0.0017395  0.0020752  0.00167847 ... 0.00021362 0.00027466 0.00024414]
# [-0.00061035 -0.00064087 -0.00057983 ... -0.0005188  -0.00048828
#  -0.00048828]
# [-6.1035156e-05 -6.1035156e-05  0.0000000e+00 ... -4.5776367e-04
#  -4.8828125e-04 -5.1879883e-04]
# [ 0.0000000e+00  6.1035156e-05  3.0517578e-05 ... -6.1035156e-04
#  -6.1035156e-04 -5.7983398e-04]
# [0.00097656 0.00100708 0.00097656 ... 0.00112915 0.00128174 0.00125122]
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 4.4177767e-05 4.5971596e-05
#  4.6736306e-05]
# [0.00106812 0.00100708 0.00094604 ... 0.00180054 0.00183105 0.00183105]
# [0.00076294 0.00073242 0.00073242 ... 0.00146484 0.00146484 0.00149536]
# [ 0.00088501  0.00088501  0.00088501 ... -0.00238037 -0.00241089
#  -0.00256348]
# [-0.0007019  -0.0007019  -0.0007019  ... -0.0005188  -0.00054932
#  -0.00054932]
# [-0.00143433 -0.0015564  -0.0015564  ...  0.0007019   0.00076294
#   0.00076294]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -5.7983398e-04
#  -6.1035156e-04 -6.1035156e-04]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -1.0375977e-03
#  -1.0375977e-03 -1.0375977e-03]
# [-0.00045776 -0.0005188  -0.00045776 ...  0.00045776  0.00045776
#   0.0005188 ]
# [6.1035156e-05 6.1035156e-05 3.0517578e-05 ... 6.4086914e-04 6.7138672e-04
#  6.7138672e-04]
# [0.00042725 0.00042725 0.00036621 ... 0.00170898 0.00177002 0.00180054]
# [-0.00195312 -0.00186157 -0.00082397 ...  0.00061035  0.00061035
#   0.00061035]
# [ 0.0000000e+00 -3.0517578e-05  3.0517578e-05 ...  9.1552734e-05
#   6.1035156e-05  6.1035156e-05]
# [ 0.          0.          0.         ... -0.00027466 -0.00030518
#  -0.00030518]
# [ 0.00045776  0.00030518  0.00027466 ... -0.00210571 -0.00222778
#  -0.0022583 ]
# [-2.2737368e-13 -9.0949470e-13 -2.2737368e-13 ...  2.3597835e-10
#  -1.8641089e-10  1.3853452e-10]
# [-0.00216675 -0.00213623 -0.0022583  ...  0.0005188   0.00057983
#   0.00061035]
# [-0.00125122 -0.00112915 -0.00112915 ...  0.00134277  0.00134277
#   0.00140381]
# [-0.0010376  -0.00100708 -0.00094604 ...  0.00042725  0.00042725
#   0.00042725]
# [ 3.6948222e-13  2.9487524e-13 -3.6948222e-13 ... -8.0618490e-09
#   7.0520785e-09 -6.0306165e-09]
# [0.00054932 0.00048828 0.00042725 ... 0.00027466 0.00033569 0.00036621]
# [ 0.00015259  0.00021362  0.00018311 ... -0.01138306 -0.01171875
#  -0.01196289]
# [-0.00128174 -0.00128174 -0.0012207  ... -0.00064087 -0.00064087
#  -0.00067139]
# [-0.00137329 -0.00109863 -0.00048828 ... -0.00057983 -0.00054932
#  -0.0005188 ]
# [-0.00015259 -0.00012207 -0.00015259 ...  0.00030518  0.00027466
#   0.00033569]
# [ 0.00076294  0.00076294  0.0007019  ... -0.00027466 -0.00033569
#  -0.00030518]
# [ 2.6645353e-15  1.2345680e-13 -1.1546319e-13 ... -4.1171414e-04
#  -4.1734800e-04 -3.0713310e-04]
# [-0.00085449 -0.00076294 -0.00088501 ... -0.00045776 -0.00048828
#  -0.0005188 ]
# [ 4.8828125e-04  5.1879883e-04  7.3242188e-04 ... -3.0517578e-05
#   3.0517578e-05  3.0517578e-05]
# [-0.00219727 -0.00213623 -0.0020752  ... -0.00076294 -0.00076294
#  -0.00079346]
# [-0.00082397 -0.00082397 -0.00073242 ...  0.00106812  0.0010376
#   0.0010376 ]
# [0.00024414 0.00018311 0.00021362 ... 0.00039673 0.00039673 0.00045776]
# [ 0.          0.          0.         ... -0.00793457 -0.00796509
#  -0.00799561]
# [ 0.00338745  0.00323486  0.00311279 ... -0.00036621 -0.00033569
#  -0.00036621]
# [-0.0007019  -0.00073242 -0.00082397 ... -0.00079346 -0.00082397
#  -0.00079346]
# [0.00634766 0.00619507 0.00604248 ... 0.00402832 0.00378418 0.00338745]
# [1.1596680e-03 1.2512207e-03 1.1901855e-03 ... 0.0000000e+00 9.1552734e-05
#  6.1035156e-05]
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 3.0517578e-05
#  3.0517578e-05]
# [ 0.00015259  0.00015259  0.00018311 ... -0.00097656 -0.00094604
#  -0.00094604]
# [-0.00201416 -0.00201416 -0.00195312 ... -0.00134277 -0.00125122
#  -0.00115967]
# [-0.00280762 -0.00274658 -0.00265503 ... -0.00128174 -0.00134277
#  -0.00137329]
# [0.00097656 0.00097656 0.00085449 ... 0.00033569 0.00036621 0.00039673]
# [-3.0517578e-05  1.2207031e-04  2.1362305e-04 ...  6.4086914e-04
#   6.4086914e-04  6.4086914e-04]
# [ 0.0005188   0.00048828  0.0005188  ... -0.00024414 -0.00024414
#  -0.00030518]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -1.7193346e-05
#  -1.4585301e-05 -2.4880774e-07]
# [-0.0005188  -0.00042725 -0.00024414 ... -0.00033569 -0.00030518
#  -0.00036621]
# [0.         0.         0.         ... 0.00234985 0.00247192 0.00244141]
# [-0.00076294 -0.00073242 -0.00067139 ...  0.00054932  0.0005188
#   0.0005188 ]
# [ 0.00097656  0.00097656  0.00097656 ... -0.00140381 -0.00140381
#  -0.00140381]
# [-0.00769043 -0.01412964 -0.00357056 ... -0.00064087 -0.00064087
#  -0.00064087]
# [ 0.00048828  0.00039673  0.00021362 ... -0.00140381 -0.00146484
#  -0.00140381]
# [-0.00390625 -0.0038147  -0.00372314 ... -0.00076294 -0.00158691
#  -0.0010376 ]
# [-5.4931641e-04 -5.4931641e-04 -6.4086914e-04 ... -6.1035156e-05
#  -1.2207031e-04 -1.5258789e-04]
# [-0.00015259 -0.00015259 -0.00018311 ... -0.00027466 -0.00030518
#  -0.00027466]
# [ 9.1552734e-05  9.1552734e-05  1.2207031e-04 ... -1.2207031e-04
#  -9.1552734e-05 -1.2207031e-04]
# [ 0.00201416  0.00201416  0.00192261 ... -0.00112915 -0.00109863
#  -0.00112915]
# [-6.7501560e-14  1.5187851e-13 -1.8651747e-14 ... -3.5193709e-06
#   5.4121756e-06  7.4821724e-06]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -6.6223145e-03
#  -6.6833496e-03 -6.8359375e-03]
# [-0.00042725 -0.0005188  -0.00057983 ...  0.00158691  0.0015564
#   0.0015564 ]
# [-0.00042725 -0.00027466 -0.00024414 ... -0.00076294 -0.00067139
#  -0.00064087]
# [-0.00064087 -0.00085449 -0.0010376  ... -0.00106812 -0.0010376
#  -0.00100708]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -3.0517578e-03
#  -3.2348633e-03 -3.1738281e-03]
# [ 6.1035156e-05  3.0517578e-05 -9.1552734e-05 ... -6.1035156e-05
#  -6.1035156e-05 -9.1552734e-05]
# [-0.00061035 -0.0005188  -0.00054932 ... -0.00350952 -0.00369263
#  -0.00378418]
# [0.00021362 0.00021362 0.00018311 ... 0.00027466 0.00030518 0.00027466]
# [0.00048828 0.00045776 0.00039673 ... 0.00033569 0.00030518 0.00033569]
# [ 1.0073013e-03  2.6589150e-03 -2.7053677e-03 ... -1.5064279e-07
#  -2.1782489e-07  1.7916227e-07]
# [ 0.00106812  0.00106812  0.00106812 ... -0.00259399 -0.00265503
#  -0.00283813]
# [ 0.0000000e+00 -3.0517578e-05 -3.0517578e-05 ...  2.0446777e-03
#   2.0446777e-03  2.0751953e-03]
# [-0.00027466 -0.00027466 -0.00024414 ...  0.00033569  0.00030518
#   0.00027466]
# [3.0517578e-05 0.0000000e+00 0.0000000e+00 ... 1.2725830e-02 1.2756348e-02
#  1.2878418e-02]
# [4.3029785e-03 4.2419434e-03 4.0588379e-03 ... 1.5258789e-04 1.5258789e-04
#  6.1035156e-05]
# [0.00186157 0.00186157 0.00183105 ... 0.00192261 0.00201416 0.0020752 ]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -7.6599121e-03
#  -7.6904297e-03 -7.6904297e-03]
# [ 0.0000000e+00 -6.1035156e-05 -3.0517578e-05 ... -1.0986328e-03
#  -1.0681152e-03 -1.1291504e-03]
# [ 0.00100708  0.00100708  0.00106812 ... -0.00143433 -0.00137329
#  -0.00131226]
# [0.00067139 0.00067139 0.0007019  ... 0.00143433 0.00140381 0.00146484]
# [-0.00231934 -0.00201416 -0.00201416 ... -0.00027466 -0.00027466
#  -0.00027466]
# [ 0.0027771   0.00274658  0.00268555 ... -0.00079346 -0.00082397
#  -0.00085449]
# [0.00097656 0.00085449 0.00079346 ... 0.00222778 0.0022583  0.00241089]
# [ 0.00024414  0.00024414  0.00024414 ... -0.00082397 -0.00082397
#  -0.00082397]
# [ 0.00012207  0.00015259  0.00012207 ... -0.00106812 -0.00112915
#  -0.00112915]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -5.3405762e-03
#  -5.3100586e-03 -5.3710938e-03]
# [-2.7465820e-04 -2.4414062e-04 -2.7465820e-04 ... -3.0517578e-05
#  -3.0517578e-05  3.0517578e-05]
# [-1.6784668e-03 -1.6174316e-03 -1.4953613e-03 ...  0.0000000e+00
#   6.1035156e-05  6.1035156e-05]
# [ 4.5776367e-04  3.9672852e-04  2.4414062e-04 ... -1.5258789e-04
#  -1.2207031e-04 -9.1552734e-05]
# [ 0.00015259  0.00018311  0.00018311 ... -0.00073242 -0.00082397
#  -0.00082397]
# [ 0.00067139  0.00094604  0.00115967 ... -0.00073242 -0.00067139
#  -0.0007019 ]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  7.3242188e-04
#   7.3242188e-04  7.6293945e-04]
# [0. 0. 0. ... 0. 0. 0.]
# [-0.00140381 -0.00131226 -0.00134277 ... -0.00030518 -0.00030518
#  -0.00030518]
# [ 1.2207031e-04  9.1552734e-05  1.2207031e-04 ... -7.6293945e-04
#  -7.3242188e-04 -7.6293945e-04]
# [-6.1035156e-05 -6.1035156e-05  0.0000000e+00 ...  1.5258789e-04
#   1.8310547e-04  2.4414062e-04]
# [ 0.00030518  0.00027466  0.00027466 ... -0.00045776 -0.00045776
#  -0.00042725]
# [-0.00036621 -0.00030518 -0.00027466 ... -0.0012207  -0.00119019
#  -0.00131226]
# [0.00073242 0.00067139 0.00054932 ... 0.00158691 0.00161743 0.00164795]
# [-1.2207031e-04 -1.5258789e-04 -1.5258789e-04 ...  3.0517578e-05
#   0.0000000e+00  0.0000000e+00]
# [-0.00198364 -0.00198364 -0.00140381 ...  0.00039673  0.00042725
#   0.00045776]
# [-0.00036621 -0.00161743 -0.00164795 ...  0.00027466  0.00033569
#   0.00042725]
# [-0.00036621 -0.00039673 -0.00039673 ... -0.00015259 -0.00018311
#  -0.00030518]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -6.1035156e-04
#  -6.4086914e-04 -6.4086914e-04]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -3.9672852e-04
#  -4.2724609e-04 -4.5776367e-04]
# [-1.5258789e-04 -2.1362305e-04 -3.0517578e-05 ...  0.0000000e+00
#  -6.1035156e-05  3.0517578e-05]
# [-1.4343262e-03 -2.0751953e-03 -3.0517578e-04 ...  6.1035156e-05
#   3.0517578e-05  1.2207031e-04]
# [-1.6784668e-03 -1.6479492e-03 -1.5563965e-03 ...  1.5258789e-04
#   9.1552734e-05  9.1552734e-05]
# [-0.00152588 -0.00140381 -0.00134277 ...  0.00527954  0.00546265
#   0.00561523]
# [-0.00073242 -0.00064087 -0.00064087 ... -0.00036621 -0.00042725
#  -0.00039673]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -5.7373047e-03
#  -5.6152344e-03 -5.5847168e-03]
# [-0.00030518 -0.00033569 -0.00036621 ...  0.00183105  0.00189209
#   0.00192261]
# [-0.00091553 -0.00091553 -0.00094604 ... -0.00027466 -0.00033569
#  -0.00027466]
# [0.         0.         0.         ... 0.00531006 0.00527954 0.00527954]
# [-0.00115967 -0.00100708 -0.00085449 ...  0.00091553  0.00094604
#   0.00094604]
# [ 0.          0.          0.         ... -0.00671387 -0.00683594
#  -0.00671387]
# [ 0.00231934  0.00186157  0.00128174 ... -0.00131226 -0.00134277
#  -0.00128174]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  1.0375120e-06
#  -8.8075842e-07  7.3643304e-07]
# [-0.00024414 -0.00024414 -0.00024414 ...  0.0078125   0.00805664
#   0.0083313 ]
# [-6.1035156e-05 -6.1035156e-05 -1.2207031e-04 ...  6.4086914e-04
#   6.4086914e-04  7.0190430e-04]
# [ 1.52478115e-05  1.45346239e-05 -8.37620973e-07 ...  7.58153419e-06
#   1.45976128e-05  1.04334322e-05]
# [ 0.00018311  0.00024414  0.00024414 ... -0.00073242 -0.00076294
#  -0.00067139]
# [-6.1035156e-05  3.0517578e-05 -9.1552734e-05 ...  2.1362305e-04
#   1.5258789e-04  1.2207031e-04]
# [-0.00015259 -0.00021362 -0.00021362 ...  0.00186157  0.00152588
#   0.00161743]
# [2.1205840e-05 6.2945554e-05 4.6827787e-05 ... 2.1561222e-05 3.5968813e-05
#  0.0000000e+00]
# [ 0.0005188   0.0005188   0.00048828 ... -0.00067139 -0.00064087
#  -0.00064087]
# [0.00033569 0.00045776 0.00045776 ... 0.00112915 0.00128174 0.00128174]
# [-0.0022583  -0.00302124 -0.00265503 ... -0.00082397 -0.00082397
#  -0.00085449]
# [ 1.5258789e-04  1.5258789e-04  6.1035156e-05 ... -8.5449219e-04
#  -8.5449219e-04 -8.5449219e-04]
# [ 0.00039673  0.00036621  0.00036621 ... -0.00082397 -0.00064087
#  -0.00042725]
# [ 3.6621094e-04  4.2724609e-04  4.2724609e-04 ...  0.0000000e+00
#  -3.0517578e-05  3.0517578e-05]
# [-0.00024414 -0.00024414 -0.00024414 ... -0.00183105 -0.00192261
#  -0.00192261]
# [ 0.00024414  0.00021362  0.00021362 ... -0.00500488 -0.00521851
#  -0.00534058]
# [-0.00134277 -0.00134277 -0.00128174 ... -0.0022583  -0.00228882
#  -0.00238037]
# [-1.5258789e-04 -1.8310547e-04 -9.1552734e-05 ...  6.4086914e-04
#   5.7983398e-04  6.7138672e-04]
# [-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  1.8920898e-03
#   2.0141602e-03  2.0751953e-03]
# [0.00128174 0.00119019 0.00119019 ... 0.00100708 0.00097656 0.00097656]
# [0.00012207 0.00015259 0.00018311 ... 0.00134277 0.00137329 0.00146484]
# [-0.00045776 -0.00042725 -0.00039673 ... -0.00045776 -0.00042725
#  -0.00036621]
# [ 0.00085449  0.00085449  0.00088501 ... -0.00030518 -0.00024414
#  -0.00027466]
# [ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ...  1.1596680e-03
#   1.1291504e-03  1.0375977e-03]
# [-0.00030518 -0.00030518 -0.00021362 ...  0.00091553  0.00091553
#   0.00091553]
# [0.00057983 0.00061035 0.00064087 ... 0.00018311 0.00018311 0.00015259]
# [ 3.0517578e-05  0.0000000e+00 -3.0517578e-05 ... -2.7465820e-04
#  -2.7465820e-04 -3.0517578e-04]
# [ 0.00213623  0.00183105 -0.00183105 ...  0.00064087  0.00067139
#   0.00067139]
# [0.00131226 0.00131226 0.00119019 ... 0.00384521 0.00396729 0.00415039]
# [-0.00170898 -0.00161743 -0.00149536 ... -0.00054932 -0.00054932
#  -0.00064087]
# [ 0.00247192  0.00241089  0.00244141 ... -0.00061035 -0.00064087
#  -0.00061035]
# [-0.00061035 -0.00057983 -0.0005188  ...  0.00115967  0.00115967
#   0.00119019]
# [4.8828125e-04 4.8828125e-04 4.5776367e-04 ... 6.1035156e-05 6.1035156e-05
#  6.1035156e-05]
# [ 0.00100708  0.00085449  0.0007019  ... -0.0015564  -0.00158691
#  -0.00170898]
# [-0.00064087 -0.00057983 -0.00057983 ... -0.00793457 -0.00820923
#  -0.00842285]
# [-0.00213623 -0.00265503 -0.00256348 ...  0.00073242  0.00082397
#   0.00088501]
# [ 0.00125122  0.00085449  0.00067139 ... -0.00067139 -0.00067139
#  -0.00067139]
# [ 0.00061035  0.00057983  0.0005188  ... -0.00067139 -0.00076294
#  -0.00079346]
# [-0.00027466 -0.00027466 -0.00021362 ... -0.00012207 -0.00015259
#  -0.00018311]
# [6.1035156e-05 3.0517578e-05 6.1035156e-05 ... 1.5258789e-04 6.1035156e-05
#  3.0517578e-05]
# [-0.00027466 -0.00027466 -0.00021362 ... -0.00024414 -0.00027466
#  -0.00033569]
# [-0.00128174 -0.00131226 -0.00134277 ...  0.00045776  0.00033569
#   0.00054932]
# [3.0517578e-05 0.0000000e+00 3.0517578e-05 ... 4.8828125e-04 5.1879883e-04
#  5.4931641e-04]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  8.4533691e-03
#   8.6364746e-03  8.3923340e-03]
# [-0.0005188  -0.00054932 -0.0005188  ... -0.00109863 -0.00112915
#  -0.00112915]
# [ 3.3569336e-04  6.1035156e-05  3.3569336e-04 ... -4.8828125e-04
#  -5.1879883e-04 -4.8828125e-04]
# [0.00061035 0.00061035 0.00054932 ... 0.0007019  0.00088501 0.00082397]
# [-0.00085449 -0.00079346 -0.00073242 ... -0.00018311 -0.00018311
#  -0.00024414]
# [ 0.0032959   0.00445557  0.00372314 ... -0.00164795 -0.0017395
#  -0.00177002]
# [-0.00054932 -0.0005188  -0.00048828 ...  0.00024414  0.00027466
#   0.00018311]
# [ 0.          0.          0.         ... -0.00012207 -0.00012207
#  -0.00012207]
# [ 7.1054274e-14  2.5579538e-13 -1.3145041e-13 ... -8.0198937e-05
#  -8.1165286e-05  0.0000000e+00]
# [ 0.00094604  0.00088501  0.00085449 ... -0.00228882 -0.00238037
#  -0.00247192]
# [0.0000000e+00 3.0517578e-05 0.0000000e+00 ... 2.5634766e-03 2.7160645e-03
#  2.9602051e-03]
# [-0.00061035 -0.00057983 -0.00064087 ... -0.00018311 -0.00021362
#  -0.00015259]
# [-0.00100708 -0.00097656 -0.00088501 ...  0.0007019   0.00067139
#   0.00067139]
# [ 0.00030518  0.00045776  0.00048828 ... -0.00057983 -0.00061035
#  -0.00057983]
# [-0.00094604 -0.0005188  -0.00079346 ...  0.00106812  0.00115967
#   0.00119019]
# [-0.00112915 -0.00109863 -0.00109863 ...  0.00109863  0.00112915
#   0.00112915]
# [ 6.2527761e-13 -3.9790393e-13 -3.9790393e-13 ... -7.2518473e-05
#  -1.0948990e-04  0.0000000e+00]
# [-0.00134277 -0.00134277 -0.00125122 ...  0.00112915  0.00119019
#   0.0012207 ]
# [0.00054932 0.00057983 0.00054932 ... 0.00082397 0.00097656 0.00097656]
# [ 0.          0.          0.         ... -0.00042725 -0.00042725
#  -0.00045776]
# [ 0.00033569  0.00033569  0.00033569 ... -0.00076294 -0.00079346
#  -0.00082397]
# [ 0.00106812  0.0012207   0.00134277 ... -0.00076294 -0.00082397
#  -0.00076294]
# [-0.00057983 -0.00048828 -0.00039673 ...  0.00039673  0.00042725
#   0.00039673]
# [ 0.          0.          0.         ... -0.00271606 -0.00271606
#  -0.00283813]
# [0.00048828 0.00048828 0.00036621 ... 0.00250244 0.00256348 0.00256348]
# [ 0.00137329  0.00128174  0.00125122 ... -0.00180054 -0.00183105
#  -0.00177002]
# [0.00790405 0.00778198 0.0078125  ... 0.00875854 0.00863647 0.00863647]
# [ 7.9345703e-04  7.9345703e-04  7.3242188e-04 ...  3.0517578e-05
#  -3.0517578e-05 -6.1035156e-05]
# [-0.00079346 -0.00079346 -0.00073242 ...  0.00146484  0.00119019
#   0.00082397]
# [ 0.00027466  0.00018311  0.00021362 ... -0.00036621 -0.00039673
#  -0.00042725]
# [ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ... -7.3242188e-04
#  -8.8500977e-04 -1.1291504e-03]
# [-0.00045776 -0.00045776 -0.00039673 ...  0.00161743  0.0015564
#   0.0015564 ]
# [0.00158691 0.00149536 0.00149536 ... 0.00131226 0.00128174 0.00128174]
# [3.0517578e-04 3.0517578e-04 3.6621094e-04 ... 0.0000000e+00 6.1035156e-05
#  6.1035156e-05]
# [0.0007019  0.0007019  0.0007019  ... 0.00076294 0.00082397 0.00085449]
# [0.00048828 0.00042725 0.00045776 ... 0.00112915 0.0012207  0.00128174]
# [-0.00091553 -0.00091553 -0.00088501 ... -0.00021362 -0.00018311
#  -0.00024414]
# [0.00021362 0.00021362 0.00015259 ... 0.00054932 0.00054932 0.00061035]
# [-0.00048828 -0.00042725 -0.00042725 ... -0.00039673 -0.00030518
#  -0.00030518]
# [0.00109863 0.00109863 0.00106812 ... 0.00030518 0.00024414 0.00024414]
# [0.00088501 0.00091553 0.00091553 ... 0.00045776 0.00054932 0.00067139]
# [ 0.00213623  0.00204468  0.00201416 ... -0.0038147  -0.00393677
#  -0.00396729]
# [-0.00213623 -0.0020752  -0.00201416 ...  0.00137329  0.00140381
#   0.00140381]
# [-0.00027466 -0.00024414 -0.00030518 ...  0.00015259  0.00015259
#   0.00015259]
# [ 0.00192261  0.00186157  0.00180054 ... -0.00076294 -0.00073242
#  -0.00076294]
# [ 0.00170898  0.00170898  0.0015564  ... -0.00112915 -0.0012207
#  -0.00134277]
# [-0.00030518 -0.00036621 -0.00036621 ...  0.00015259  0.00015259
#   0.00018311]
# [-9.1552734e-05 -1.2207031e-04 -9.1552734e-05 ...  4.2724609e-04
#   4.2724609e-04  3.6621094e-04]
# [ 0.00189209  0.00186157  0.00183105 ... -0.00079346 -0.00085449
#  -0.00091553]
# [-3.0517578e-04 -4.2724609e-04 -4.2724609e-04 ... -3.3569336e-04
#  -6.1035156e-05 -3.0517578e-05]
# [-0.00021362 -0.00015259 -0.00015259 ...  0.00079346  0.00082397
#   0.00088501]
# [ 3.0517578e-05 -3.0517578e-05  0.0000000e+00 ... -5.4931641e-04
#  -5.1879883e-04 -5.1879883e-04]
# [-0.00015259 -0.00015259 -0.00015259 ... -0.00021362 -0.00024414
#  -0.00024414]
# [-7.0190430e-04 -6.4086914e-04 -6.1035156e-04 ... -9.1552734e-05
#   0.0000000e+00  0.0000000e+00]
# [ 0.00125122  0.00112915  0.00109863 ... -0.00134277 -0.00134277
#  -0.0010376 ]
# [-2.4414062e-04 -2.4414062e-04 -2.7465820e-04 ... -9.1552734e-05
#  -6.1035156e-05 -9.1552734e-05]
# [0.00057983 0.00045776 0.0005188  ... 0.00045776 0.0005188  0.00048828]
# [-0.00024414 -0.00021362 -0.00018311 ... -0.00024414 -0.00024414
#  -0.00021362]
# [-9.7656250e-04 -9.7656250e-04 -9.1552734e-04 ...  1.2207031e-04
#   1.2207031e-04  9.1552734e-05]
# [ 0.0000000e+00  3.0517578e-05 -3.0517578e-05 ...  5.4321289e-03
#   5.4321289e-03  5.3100586e-03]
# [-0.00137329 -0.00137329 -0.00134277 ...  0.00018311  0.00021362
#   0.00018311]
# [ 0.0032959   0.00323486  0.00317383 ... -0.00094604 -0.00094604
#  -0.00100708]
# [0.00109863 0.00134277 0.00125122 ... 0.00094604 0.00097656 0.00100708]
# [-3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -1.8310547e-04
#  -2.4414062e-04 -3.3569336e-04]
# [-0.00042725 -0.00033569 -0.00027466 ... -0.00067139 -0.00057983
#  -0.00057983]
# [ 0.0000000e+00 -6.1035156e-05  0.0000000e+00 ... -2.6855469e-03
#  -2.7465820e-03 -2.7770996e-03]
# [-0.00106812 -0.00097656 -0.00085449 ... -0.00177002 -0.00177002
#  -0.00189209]
# [ 0.0000000e+00 -3.0517578e-05  6.1035156e-05 ... -6.4086914e-04
#  -6.4086914e-04 -5.7983398e-04]
# [3.6621094e-04 3.6621094e-04 3.9672852e-04 ... 0.0000000e+00 3.0517578e-05
#  0.0000000e+00]
# [-5.4931641e-04 -5.1879883e-04 -4.2724609e-04 ... -9.1552734e-05
#  -1.5258789e-04 -1.5258789e-04]
# [-1.5258789e-04 -1.2207031e-04 -3.0517578e-05 ...  3.3569336e-04
#   3.6621094e-04  3.9672852e-04]
# [ 0.00024414  0.00024414  0.00018311 ... -0.00057983 -0.00054932
#  -0.00057983]
# [ 1.8310547e-04  2.1362305e-04  1.8310547e-04 ... -3.0517578e-05
#   0.0000000e+00 -3.0517578e-05]
# [ 0.0000000e+00 -6.1035156e-05 -3.0517578e-05 ...  3.9672852e-04
#   3.6621094e-04  3.6621094e-04]
# [-0.00057983 -0.00057983 -0.00048828 ... -0.0007019  -0.00079346
#  -0.00079346]
# [-0.00036621 -0.00036621 -0.00033569 ... -0.00161743 -0.00170898
#  -0.00170898]
# [-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  2.0446777e-03
#   2.1667480e-03  2.2277832e-03]
# [-3.0517578e-04 -1.8310547e-04 -9.1552734e-05 ...  1.0681152e-03
#   1.0986328e-03  1.0986328e-03]
# [ 0.00146484  0.00177002  0.0020752  ... -0.00219727 -0.00222778
#  -0.0022583 ]
# [-3.0517578e-05 -3.0517578e-05  3.0517578e-05 ...  3.9062500e-03
#   4.0283203e-03  4.0893555e-03]
# [-0.0020752  -0.00210571 -0.00198364 ... -0.00036621 -0.00039673
#  -0.00042725]
# [ 1.2207031e-04  6.1035156e-05  3.0517578e-05 ... -6.7138672e-04
#  -7.0190430e-04 -7.0190430e-04]
# [0.00036621 0.00030518 0.00033569 ... 0.00054932 0.00054932 0.00054932]
# [ 0.00061035  0.00064087  0.00057983 ... -0.00054932 -0.00054932
#  -0.00061035]
# [ 0.00085449  0.00082397  0.00082397 ... -0.00085449 -0.00091553
#  -0.00094604]
# [0.00042725 0.00045776 0.00042725 ... 0.00024414 0.00024414 0.00021362]
# [-0.00033569 -0.00036621 -0.00033569 ... -0.00128174 -0.00137329
#  -0.00143433]
# [0.00106812 0.00106812 0.0010376  ... 0.00222778 0.0022583  0.00231934]
# [-0.00042725 -0.00042725 -0.00045776 ...  0.00149536  0.00137329
#   0.00152588]
# [-0.00088501 -0.00082397 -0.00082397 ...  0.00076294  0.00082397
#   0.00088501]
# [-0.00061035 -0.00061035 -0.00061035 ...  0.00048828  0.0005188
#   0.0005188 ]
# [0.00109863 0.00109863 0.0010376  ... 0.00024414 0.00030518 0.00030518]
# [1.8005371e-03 1.7700195e-03 1.7395020e-03 ... 6.1035156e-05 3.0517578e-05
#  0.0000000e+00]
# [0.00048828 0.00048828 0.00048828 ... 0.00149536 0.00152588 0.0015564 ]
# [ 0.00262451  0.00360107  0.00286865 ... -0.00039673 -0.00039673
#  -0.00039673]
# [ 0.0000000e+00  3.0517578e-05  0.0000000e+00 ... -3.6010742e-03
#  -3.6010742e-03 -3.6315918e-03]
# [-3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -7.9345703e-04
#  -8.8500977e-04 -8.5449219e-04]
# [9.1552734e-05 1.5258789e-04 1.2207031e-04 ... 8.5449219e-04 8.8500977e-04
#  9.1552734e-04]
# [-0.00140381 -0.00134277 -0.00134277 ...  0.00112915  0.00106812
#   0.0010376 ]
# [ 0.0007019   0.00061035  0.00064087 ... -0.00015259 -0.00018311
#  -0.00024414]
# [ 3.0517578e-05  0.0000000e+00  3.0517578e-05 ... -1.8310547e-04
#  -1.8310547e-04 -1.8310547e-04]
# [-0.00027466 -0.00030518 -0.00030518 ...  0.00140381  0.00149536
#   0.00149536]
# [-0.00030518 -0.00054932 -0.00079346 ... -0.0005188  -0.00048828
#  -0.0005188 ]
# [-0.00112915 -0.00106812 -0.00082397 ...  0.0105896   0.01043701
#   0.01040649]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  1.4038086e-03
#   1.4648438e-03  1.3427734e-03]
# [ 0.00149536  0.00143433  0.00140381 ... -0.00140381 -0.00143433
#  -0.00143433]
# [0.00018311 0.00015259 0.00018311 ... 0.00042725 0.00054932 0.00048828]
# [-3.0517578e-05  3.0517578e-05  0.0000000e+00 ... -1.1901855e-03
#  -1.1901855e-03 -1.1596680e-03]
# [ 0.00253296  0.00244141  0.00228882 ... -0.00167847 -0.00177002
#  -0.00186157]
# [0.00238037 0.00219727 0.00216675 ... 0.00057983 0.00064087 0.0007019 ]
# [-0.0007019   0.00112915 -0.00192261 ...  0.00170898  0.00180054
#   0.00180054]
# [ 0.00546265  0.00558472  0.00558472 ... -0.01168823 -0.0116272
#  -0.01184082]
# [ 0.00033569  0.00036621  0.00039673 ... -0.00073242 -0.00079346
#  -0.00079346]
# [-6.1035156e-05 -3.0517578e-05 -6.1035156e-05 ...  1.8310547e-04
#   1.8310547e-04  1.8310547e-04]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -2.1972656e-03
#  -2.2277832e-03 -2.1972656e-03]
# [-0.00018311 -0.00021362 -0.00018311 ... -0.00076294 -0.00082397
#  -0.00094604]
# [1.2207031e-04 1.2207031e-04 3.0517578e-05 ... 9.1552734e-04 1.1901855e-03
#  6.1035156e-04]
# [0.00149536 0.0015564  0.00164795 ... 0.00167847 0.00170898 0.00183105]
# [0.00045776 0.00048828 0.00054932 ... 0.00054932 0.00057983 0.0005188 ]
# [-0.00033569 -0.00027466 -0.00033569 ... -0.00036621 -0.00039673
#  -0.00039673]
# [4.5776367e-04 3.6621094e-04 3.3569336e-04 ... 1.2207031e-04 1.2207031e-04
#  9.1552734e-05]
# [ 0.00274658  0.00262451  0.00250244 ... -0.0007019  -0.0007019
#  -0.00079346]
# [-1.2207031e-03 -1.2207031e-03 -1.2207031e-03 ... -1.2207031e-04
#  -9.1552734e-05 -6.1035156e-05]
# [0.0000000e+00 3.0517578e-05 0.0000000e+00 ... 7.9345703e-04 8.5449219e-04
#  8.8500977e-04]
# [-0.00109863 -0.0010376  -0.00106812 ... -0.00018311 -0.00021362
#  -0.00027466]
# [-0.00021362 -0.00030518 -0.00039673 ...  0.00091553  0.00097656
#   0.00100708]
# [-0.02975464 -0.02954102 -0.02978516 ...  0.0149231   0.01519775
#   0.01519775]
# [-0.00115967 -0.0012207  -0.00112915 ...  0.00036621  0.00033569
#   0.00036621]
# [-0.00097656 -0.00091553 -0.00076294 ...  0.00137329  0.00137329
#   0.00146484]
# [-0.00192261 -0.00186157 -0.00183105 ...  0.00088501  0.0010376
#   0.00100708]
# [-0.00115967 -0.00119019 -0.00115967 ...  0.00030518  0.00030518
#   0.00030518]
# [-0.00048828 -0.00039673 -0.00036621 ... -0.00109863 -0.00112915
#  -0.00112915]
# [-0.00015259 -0.00012207 -0.00015259 ... -0.0027771  -0.00286865
#  -0.00289917]
# [ 0.00198364  0.00195312  0.00186157 ... -0.00073242 -0.00076294
#  -0.00079346]
# [-5.1879883e-04 -4.8828125e-04 -4.2724609e-04 ...  1.2207031e-04
#   1.2207031e-04  9.1552734e-05]
# [-0.00027466 -0.00021362 -0.00027466 ...  0.0017395   0.00180054
#   0.00180054]
# [ 0.00268555  0.0027771   0.00253296 ... -0.00357056 -0.00369263
#  -0.00372314]
# [-1.2207031e-04 -1.2207031e-04 -9.1552734e-05 ... -1.6479492e-03
#  -1.6784668e-03 -1.5563965e-03]
# [ 0.00045776  0.00039673  0.00042725 ... -0.00048828 -0.00054932
#  -0.00048828]
# [-0.00082397 -0.00094604 -0.00073242 ... -0.00024414 -0.00024414
#  -0.00021362]
# [0.00064087 0.00064087 0.00054932 ... 0.00106812 0.00109863 0.00109863]
# [-3.0517578e-05  3.0517578e-05  0.0000000e+00 ...  9.4604492e-03
#   9.3383789e-03  9.4299316e-03]
# [ 0.          0.          0.         ... -0.00085449 -0.00079346
#  -0.00076294]
# [-0.00021362 -0.00018311 -0.00015259 ...  0.00073242  0.00073242
#   0.00073242]
# [-4.8828125e-04 -2.1362305e-04  9.1552734e-05 ... -5.4931641e-04
#  -4.8828125e-04 -5.1879883e-04]
# [-0.00112915 -0.00106812 -0.00106812 ...  0.00018311  0.00021362
#   0.00018311]
# [ 0.00149536  0.00143433  0.00137329 ... -0.0039978  -0.00415039
#  -0.00427246]
# [6.1035156e-05 6.1035156e-05 0.0000000e+00 ... 9.4604492e-04 9.4604492e-04
#  1.0681152e-03]
# [ 0.00021362  0.00167847  0.00079346 ... -0.00119019 -0.00119019
#  -0.00119019]
# [-0.0005188  -0.00045776 -0.00045776 ... -0.00112915 -0.00106812
#  -0.00109863]
# [6.1035156e-05 9.1552734e-05 6.1035156e-05 ... 1.9226074e-03 2.0446777e-03
#  2.1057129e-03]
# [-0.00082397 -0.00085449 -0.00079346 ...  0.00021362  0.00018311
#   0.00015259]
# [0.         0.         0.         ... 0.00067139 0.00067139 0.0007019 ]
# [-2.7465820e-04 -3.0517578e-04 -3.0517578e-04 ...  6.1035156e-05
#   0.0000000e+00  3.0517578e-05]
# [-9.1552734e-05 -1.5258789e-04 -1.8310547e-04 ... -1.5258789e-04
#  -1.2207031e-04 -1.5258789e-04]
# [-0.00021362 -0.00042725 -0.00039673 ... -0.00054932 -0.00057983
#  -0.00054932]
# [-0.00033569 -0.00036621 -0.00039673 ...  0.00030518  0.00030518
#   0.00033569]
# [6.1035156e-05 9.1552734e-05 9.1552734e-05 ... 4.2724609e-04 4.5776367e-04
#  5.4931641e-04]
# [0.00363159 0.00317383 0.00286865 ... 0.00219727 0.00219727 0.0022583 ]
# [ 0.00115967  0.00112915  0.00106812 ... -0.00054932 -0.00057983
#  -0.00064087]
# [ 0.00656128  0.00631714  0.00601196 ... -0.00039673 -0.00054932
#  -0.00061035]
# [ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ... -6.7138672e-04
#  -6.7138672e-04 -7.0190430e-04]
# [-0.00027466 -0.00036621 -0.00033569 ...  0.00100708  0.0010376
#   0.00106812]
# [1.1291504e-03 5.1879883e-04 9.1552734e-05 ... 6.1035156e-05 6.1035156e-05
#  9.1552734e-05]
# [-9.1552734e-04 -8.8500977e-04 -8.8500977e-04 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05]
# [-0.0010376  -0.00097656 -0.00085449 ... -0.00024414 -0.00018311
#  -0.00018311]
# [-0.00012207 -0.00012207 -0.00012207 ... -0.00067139 -0.0007019
#  -0.00073242]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  1.2512207e-03
#   1.2207031e-03  1.1596680e-03]
# [ 0.00033569  0.00012207 -0.00015259 ...  0.00021362  0.00021362
#   0.00021362]
# [-0.00125122 -0.00119019 -0.00109863 ... -0.0010376  -0.00106812
#  -0.00100708]
# [-0.00238037 -0.00231934 -0.00228882 ...  0.00018311  0.00018311
#   0.00018311]
# [ 0.00097656  0.00100708  0.00097656 ... -0.0032959  -0.00338745
#  -0.00344849]
# [0.00265503 0.00274658 0.00268555 ... 0.00662231 0.00683594 0.00701904]
# [ 0.00204468  0.00198364  0.00192261 ... -0.00015259 -0.00015259
#  -0.00021362]
# [-4.7560661e-08  5.0940116e-08 -5.3317365e-08 ...  1.1913101e-05
#  -3.2512457e-07  1.7754849e-07]
# [0.00036621 0.00030518 0.00039673 ... 0.00018311 0.00015259 0.00021362]
# [-0.0085144  -0.0083313  -0.00802612 ...  0.00653076  0.00668335
#   0.00686646]
# [ 0.0000000e+00  0.0000000e+00  3.0517578e-05 ... -3.6621094e-04
#  -3.6621094e-04 -3.9672852e-04]
# [ 0.0010376   0.0010376   0.00097656 ... -0.00100708 -0.00091553
#  -0.00085449]
# [-0.02243042 -0.02252197 -0.02282715 ...  0.00802612  0.00805664
#   0.00805664]
# [-0.00064087 -0.0007019  -0.00067139 ... -0.00115967 -0.00112915
#  -0.0012207 ]
# [0.00018311 0.00018311 0.00012207 ... 0.00137329 0.00140381 0.00146484]
# [ 0.0000000e+00  3.0517578e-05  0.0000000e+00 ... -3.0517578e-05
#  -3.0517578e-05  0.0000000e+00]
# [ 0.00152588  0.00119019  0.00088501 ... -0.00054932 -0.00054932
#  -0.00064087]
# [-0.00027466 -0.00024414 -0.00021362 ...  0.00085449  0.00088501
#   0.00094604]
# [-0.00064087 -0.00067139 -0.00064087 ... -0.00097656 -0.00109863
#  -0.00109863]
# [-0.0002322  -0.00013077  0.00039729 ...  0.00014592  0.00013047
#   0.00010271]
# [0.00457764 0.00463867 0.00460815 ... 0.00018311 0.00018311 0.00015259]
# [ 3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -1.6265869e-02
#  -1.6418457e-02 -1.6418457e-02]
# [-3.0517578e-05 -3.9672852e-04 -3.6621094e-04 ... -3.0517578e-03
#  -3.4790039e-03 -3.9672852e-03]
# [0.00134277 0.00149536 0.0012207  ... 0.00100708 0.0010376  0.00112915]
# [ 0.00067139  0.00064087  0.00064087 ... -0.00082397 -0.00079346
#  -0.00088501]
# [-2.1362305e-04 -1.5258789e-04 -2.1362305e-04 ...  6.1035156e-05
#   9.1552734e-05  3.0517578e-05]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -3.0212402e-03
#  -3.0212402e-03 -3.0517578e-03]
# [ 1.8310547e-04  9.1552734e-05  3.0517578e-05 ... -8.5449219e-04
#  -8.8500977e-04 -9.4604492e-04]
# [-0.00018311 -0.00024414 -0.00030518 ... -0.00024414 -0.00027466
#  -0.00027466]
# [ 0.          0.          0.         ... -0.00643921 -0.00650024
#  -0.00646973]
# [ 2.7465820e-04  2.1362305e-04  9.1552734e-05 ... -1.2207031e-04
#  -1.2207031e-04 -1.2207031e-04]
# [-0.00015259 -0.00015259 -0.00021362 ...  0.00039673  0.00039673
#   0.00045776]
# [ 0.          0.          0.         ... -0.00082397 -0.00082397
#  -0.00088501]
# [-0.00027466 -0.00027466 -0.00027466 ...  0.00125122  0.00125122
#   0.00128174]
# [9.1552734e-05 3.0517578e-05 0.0000000e+00 ... 3.0517578e-05 0.0000000e+00
#  6.1035156e-05]
# [ 0.00018311  0.00018311  0.00012207 ... -0.00061035 -0.00061035
#  -0.00064087]
# [-0.00048828 -0.00048828 -0.0005188  ...  0.00057983  0.00054932
#   0.00054932]
# [-0.00048828 -0.00045776 -0.00042725 ...  0.00091553  0.00091553
#   0.00091553]
# [-0.00283813 -0.00280762 -0.00250244 ...  0.00094604  0.00100708
#   0.00094604]
# [ 0.00088501  0.00088501  0.00091553 ... -0.0012207  -0.00131226
#  -0.00134277]
# [ 3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -9.1552734e-05 -1.2207031e-04]
# [ 1.2512207e-03  1.2207031e-03  1.1901855e-03 ... -9.1552734e-05
#  -9.1552734e-05 -1.5258789e-04]
# [ 0.0000000e+00  0.0000000e+00 -6.1035156e-05 ...  1.6479492e-03
#   1.8310547e-03  1.8615723e-03]
# [-0.00201416 -0.00192261 -0.0017395  ...  0.00152588  0.00158691
#   0.00167847]
# [-0.00079346 -0.00073242 -0.00076294 ... -0.00030518 -0.00036621
#  -0.00039673]
# [-0.00100708 -0.00091553 -0.00085449 ... -0.00091553 -0.00106812
#  -0.00109863]
# [-0.0032959  -0.00311279 -0.00299072 ... -0.00476074 -0.00494385
#  -0.00506592]
# [ 1.2207031e-04 -3.0517578e-05 -2.7465820e-04 ...  4.2724609e-04
#   4.5776367e-04  4.2724609e-04]
# [ 0.00106812  0.00097656  0.00094604 ... -0.00137329 -0.00143433
#  -0.00146484]
# [ 0.0000000e+00  3.0517578e-05  0.0000000e+00 ... -8.5449219e-04
#  -8.8500977e-04 -7.9345703e-04]
# [ 0.0000000e+00 -3.0517578e-05  3.0517578e-05 ...  1.7089844e-03
#   1.6784668e-03  1.6479492e-03]
# [ 0.00128174  0.00119019  0.00100708 ... -0.00061035 -0.0007019
#  -0.00079346]
# [ 0.0007019  -0.00146484  0.01315308 ... -0.00671387 -0.00674438
#  -0.00671387]
# [-0.00473022 -0.0045166  -0.00439453 ... -0.00146484 -0.00140381
#  -0.00134277]
# [-0.00015259 -0.00012207 -0.00012207 ... -0.00082397 -0.0007019
#  -0.00073242]
# [0.00119019 0.0012207  0.00128174 ... 0.00286865 0.00286865 0.00283813]
# [0.00115967 0.00088501 0.00054932 ... 0.00015259 0.00018311 0.00018311]
# [ 0.00018311  0.00018311  0.00015259 ... -0.00012207 -0.00015259
#  -0.00018311]
# [-0.00045776 -0.00039673 -0.00036621 ... -0.00057983 -0.00064087
#  -0.00057983]
# [4.8828125e-04 3.0517578e-04 1.8310547e-04 ... 3.0517578e-05 3.0517578e-05
#  3.0517578e-05]
# [-0.00073242 -0.00067139 -0.00064087 ... -0.00024414 -0.00030518
#  -0.00027466]
# [ 0.00042725  0.00039673  0.00048828 ... -0.00097656 -0.00097656
#  -0.00094604]
# [ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ... -7.9345703e-04
#  -7.6293945e-04 -7.6293945e-04]
# [9.1552734e-05 1.5258789e-04 1.2207031e-04 ... 9.1552734e-05 9.1552734e-05
#  1.2207031e-04]
# [ 0.00045776  0.00048828  0.00045776 ... -0.00054932 -0.00054932
#  -0.0005188 ]
# [ 0.00085449  0.00082397  0.00079346 ... -0.00030518 -0.00033569
#  -0.00036621]
# [-0.00994873 -0.00918579 -0.00872803 ...  0.00018311  0.00021362
#   0.00018311]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -1.7053026e-13
#   5.6843419e-14  0.0000000e+00]
# [ 0.00048828  0.00057983 -0.00018311 ... -0.00082397 -0.00082397
#  -0.00088501]
# [-0.00073242 -0.00076294 -0.00076294 ... -0.00094604 -0.00091553
#  -0.00091553]
# [-6.1035156e-05 -3.0517578e-05 -6.1035156e-05 ...  1.2207031e-04
#   3.0517578e-05  6.1035156e-05]
# [ 1.3122559e-03  1.3122559e-03  1.3122559e-03 ... -9.1552734e-05
#  -1.2207031e-04 -9.1552734e-05]
# [ 1.8310547e-04  0.0000000e+00  6.1035156e-05 ... -1.8310547e-04
#  -6.1035156e-05 -9.1552734e-05]
# [3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 1.4038086e-03 1.5258789e-03
#  1.6479492e-03]
# [-0.00045776 -0.00042725 -0.00042725 ... -0.00054932 -0.00054932
#  -0.0005188 ]
# [-0.00442505 -0.00427246 -0.0039978  ... -0.00082397 -0.00082397
#  -0.00082397]
# [0.00250244 0.00228882 0.00210571 ... 0.00018311 0.00015259 0.00015259]
# [-0.00057983 -0.00134277 -0.00201416 ...  0.0005188   0.00048828
#   0.00048828]
# [-0.00164795 -0.00183105 -0.00259399 ...  0.00198364  0.00204468
#   0.00213623]
# [-0.00021362 -0.00021362 -0.00030518 ... -0.00036621 -0.00039673
#  -0.00042725]
# [-1.1437730e-04 -2.1309748e-04  7.6834622e-05 ... -1.6887931e-04
#  -1.8499188e-04 -2.5667649e-04]
# [ 1.2207031e-04  9.1552734e-05  9.1552734e-05 ... -3.0517578e-04
#  -2.7465820e-04 -3.0517578e-04]
# [0.00320435 0.00317383 0.00311279 ... 0.00271606 0.00283813 0.00253296]
# [-3.3874512e-03 -3.3569336e-03 -3.2043457e-03 ... -6.1035156e-05
#   0.0000000e+00 -6.1035156e-05]
# [-9.1552734e-05 -9.1552734e-05 -6.1035156e-05 ... -8.8500977e-04
#  -8.8500977e-04 -8.5449219e-04]
# [-0.00012207 -0.00015259 -0.00018311 ...  0.00042725  0.00042725
#   0.00045776]
# [-0.00024414 -0.00012207 -0.00012207 ...  0.0010376   0.00115967
#   0.00115967]
# [-5.1879883e-04 -6.1035156e-04 -6.4086914e-04 ...  0.0000000e+00
#   0.0000000e+00  3.0517578e-05]
# [ 0.00042725  0.00042725  0.00036621 ... -0.00024414 -0.00024414
#  -0.00024414]
# [-0.00131226 -0.00131226 -0.0012207  ...  0.00033569  0.00027466
#   0.00021362]
# [2.4414062e-04 1.8310547e-04 9.1552734e-05 ... 4.5776367e-04 4.2724609e-04
#  4.2724609e-04]
# [0.00457764 0.00439453 0.00430298 ... 0.00036621 0.00036621 0.00036621]
# [-0.00039673 -0.00039673 -0.00039673 ...  0.00030518  0.00030518
#   0.00027466]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -6.1035156e-04
#  -7.3242188e-04 -7.9345703e-04]
# [-0.00137329 -0.00137329 -0.00137329 ...  0.00067139  0.00067139
#   0.00057983]
# [ 1.0070801e-03  9.4604492e-04  9.1552734e-04 ...  0.0000000e+00
#   0.0000000e+00 -9.1552734e-05]
# [ 0.00085449  0.00091553  0.00097656 ... -0.0015564  -0.0015564
#  -0.00161743]
# [-0.00097656 -0.00088501 -0.00088501 ...  0.00125122  0.00128174
#   0.00134277]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  9.1552734e-04
#   9.4604492e-04  1.0375977e-03]
# [-4.2724609e-04 -1.2207031e-04  9.1552734e-05 ... -3.0517578e-04
#  -3.3569336e-04 -2.7465820e-04]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  1.5502930e-02
#   1.5411377e-02  1.5289307e-02]
# [0.         0.         0.         ... 0.00186157 0.00192261 0.00195312]
# [0.00067139 0.00076294 0.00079346 ... 0.00393677 0.0039978  0.00408936]
# [0.00149536 0.00152588 0.00140381 ... 0.00045776 0.00036621 0.00030518]
# [-4.3334961e-03 -4.1503906e-03 -4.0893555e-03 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00]
# [ 1.5258789e-04  1.2207031e-04  6.1035156e-05 ... -2.4414062e-04
#  -3.0517578e-04 -3.3569336e-04]
# [0.00119019 0.0012207  0.00119019 ... 0.00057983 0.00057983 0.00057983]
# [-0.00048828 -0.00048828 -0.00048828 ... -0.00024414 -0.00021362
#  -0.00027466]
# [-0.00048828 -0.00048828 -0.00042725 ... -0.00085449 -0.00088501
#  -0.00088501]
# [ 0.00119019  0.00125122  0.00128174 ... -0.00109863 -0.00112915
#  -0.00112915]
# [-0.00152588 -0.00146484 -0.00143433 ... -0.00030518 -0.00036621
#  -0.00042725]
# [-0.00024414 -0.00021362 -0.00024414 ... -0.00100708 -0.00109863
#  -0.00106812]
# [0.00045776 0.00045776 0.00045776 ... 0.00256348 0.00274658 0.00286865]
# [-3.0517578e-05 -4.8828125e-04 -3.6621094e-04 ...  3.9672852e-04
#   3.6621094e-04  3.9672852e-04]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  5.2288806e-07
#  -4.6711784e-07  0.0000000e+00]
# [-1.5258789e-04 -1.5258789e-04 -2.7465820e-04 ...  0.0000000e+00
#  -3.0517578e-05 -6.1035156e-05]
# [0.00024414 0.00024414 0.00024414 ... 0.00143433 0.00146484 0.00146484]
# [ 1.8310547e-04  1.5258789e-04  9.1552734e-05 ... -1.2207031e-04
#  -9.1552734e-05 -9.1552734e-05]
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  6.8930603e-09
#  -5.9872036e-09  5.2104951e-09]
# [0.00024414 0.00021362 0.00027466 ... 0.00061035 0.00064087 0.00067139]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  7.6904297e-03
#   7.6293945e-03  7.7514648e-03]
# [ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -8.9721680e-03
#  -9.0332031e-03 -8.9111328e-03]
# [-0.00088501 -0.00061035 -0.00064087 ...  0.0007019   0.00061035
#   0.00064087]
# [ 0.0000000e+00  3.0517578e-05  0.0000000e+00 ... -3.0517578e-05
#  -6.1035156e-05 -9.1552734e-05]
# [0.00134277 0.00131226 0.00134277 ... 0.00115967 0.00119019 0.0012207 ]

# %%
result = test_dataset.map(predict, batched=True, batch_size=8)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
label_names = [config.id2label[i] for i in range(config.num_labels)]
label_names
# Out:
# ['angry', 'happy', 'neutral', 'sad', 'surprise']

# %%
y_true = [config.label2id[name] for name in result["emotion"]]
y_pred = result["predicted"]

print(y_true[:5])
print(y_pred[:5])
# Out:
# [3, 1, 4, 0, 3]
# [1, 1, 1, 1, 1]

# %%
print(classification_report(y_true, y_pred, target_names=label_names, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#        angry       1.00      0.00      0.00       101
#        happy       0.20      1.00      0.34       101
#      neutral       1.00      0.00      0.00       102
#          sad       1.00      0.00      0.00        90
#     surprise       1.00      0.00      0.00       106
#
#     accuracy                           0.20       500
#    macro avg       0.84      0.20      0.07       500
# weighted avg       0.84      0.20      0.07       500

# %% [markdown]
# ### Prediction

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio
from transformers import AutoConfig, Wav2Vec2Processor

import librosa
import IPython.display as ipd
import numpy as np
import pandas as pd

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sampling_rate = processor.feature_extractor.sampling_rate

# %%
def speech_file_to_array_fn(path, sampling_rate):
    speech_array, _sampling_rate = torchaudio.load(path)
    resampler = torchaudio.transforms.Resample(_sampling_rate)
    speech = resampler(speech_array).squeeze().numpy()
    return speech


def predict(path, sampling_rate):
    speech = speech_file_to_array_fn(path, sampling_rate)
    features = processor(
        speech,
        sampling_rate=sampling_rate,
        return_tensors="pt",
        padding=True,
        return_attention_mask=True,
    )

    input_values = features.input_values.to(device)
    attention_mask = features.attention_mask.to(device)

    with torch.no_grad():
        logits = model(input_values, attention_mask=attention_mask).logits

    print(logits.shape)

    scores = F.softmax(logits, dim=1).detach().cpu().numpy()[0]
    outputs = [
        {"Emotion": config.id2label[i], "Score": f"{round(score * 100, 3):.1f}%"}
        for i, score in enumerate(scores)
    ]
    return outputs


STYLES = """
<style>
div.display_data {
    margin: 0 auto;
    max-width: 500px;
}
table.xxx {
    margin: 50px !important;
    float: right !important;
    clear: both !important;
}
table.xxx td {
    min-width: 300px !important;
    text-align: center !important;
}
</style>
""".strip()


def prediction(df_row):
    path, emotion = df_row["path"], df_row["emotion"]
    df = pd.DataFrame([{"Emotion": emotion}])
    setup = {
        "border": 2,
        "show_dimensions": True,
        "justify": "center",
        "classes": "xxx",
        "escape": False,
    }
    ipd.display(ipd.HTML(STYLES + df.to_html(**setup) + "<br />"))
    speech, sr = torchaudio.load(path)
    speech = speech[0].numpy().squeeze()
    speech = librosa.resample(y=np.asarray(speech), orig_sr=sr, target_sr=sampling_rate)
    ipd.display(ipd.Audio(data=np.asarray(speech), autoplay=True, rate=sampling_rate))

    outputs = predict(path, sampling_rate)
    r = pd.DataFrame(outputs)
    ipd.display(ipd.HTML(STYLES + r.to_html(**setup) + "<br />"))

# %%
test = pd.read_csv("../data/emotion_test.csv", sep="\t")
test.head()
# Out:
#               Name                                               path  \
# 0  0018_001341.wav  ../data/Emotion_Speech_Dataset/English\0018\Sa...
# 1  0012_000931.wav  ../data/Emotion_Speech_Dataset/English\0012\Ha...
# 2  0020_001526.wav  ../data/Emotion_Speech_Dataset/English\0020\Su...
# 3  0017_000538.wav  ../data/Emotion_Speech_Dataset/English\0017\An...
# 4  0018_001330.wav  ../data/Emotion_Speech_Dataset/English\0018\Sa...
#
#     emotion
# 0       sad
# 1     happy
# 2  surprise
# 3     angry
# 4       sad

# %%
prediction(test.iloc[5])
# Out:
# <style>
# div.display_data {
#     margin: 0 auto;
#     max-width: 500px;
# }
# table.xxx {
#     margin: 50px !important;
#     float: right !important;
#     clear: both !important;
# }
# table.xxx td {
#     min-width: 300px !important;
#     text-align: center !important;
# }
# </style><table border="2" class="dataframe xxx">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Emotion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>angry</td>
#     </tr>
#   </tbody>
# </table>
# <p>1 rows × 1 columns</p><br />
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# torch.Size([1, 5])
# <style>
# div.display_data {
#     margin: 0 auto;
#     max-width: 500px;
# }
# table.xxx {
#     margin: 50px !important;
#     float: right !important;
#     clear: both !important;
# }
# table.xxx td {
#     min-width: 300px !important;
#     text-align: center !important;
# }
# </style><table border="2" class="dataframe xxx">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Emotion</th>
#       <th>Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>angry</td>
#       <td>19.0%</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>happy</td>
#       <td>23.1%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>neutral</td>
#       <td>17.9%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sad</td>
#       <td>21.0%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>surprise</td>
#       <td>19.1%</td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 2 columns</p><br />
